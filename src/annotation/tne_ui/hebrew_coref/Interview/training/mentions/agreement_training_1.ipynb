# %%
% load_ext autoreload
% autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from mention_agreemnet_utils import process_annotations, read_annotation_data

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../../mention_annotation_data"

# %%
set(list(range(65, 69)))  #to fix
# Out:
# {65, 66, 67, 68, 69}

# %%
file_by_annotator = read_annotation_data(conllu_annotated_files_path, specific_files=set(list(range(65, 69))),
                                         exclude={'Shaked', 'Arbel', 'Ido', 'Yuval Sagi', 'Bar Shwarts', 'Aviv Sason'})

# %%
process_annotations(file_by_annotator)
# Out:
# 0.7369668246445498

# %%
for ann in ['Itay', 'Hadar', 'Ariela']:
    for gold in ['Elisheva', 'Consolidation']:
        keys = {key: file_by_annotator[key] for key in [ann, gold] if key in file_by_annotator}

        print(f"Agreement for {ann}:{gold}: {process_annotations(keys)}")
# Out:
# Agreement for Itay:Elisheva: 0.7262569832402235
# Agreement for Itay:Consolidation: 0.7158774373259053
# Agreement for Hadar:Elisheva: 0.7926509186351706
# Agreement for Hadar:Consolidation: 0.7322834645669292
# Agreement for Ariela:Elisheva: 0.681704260651629
# Agreement for Ariela:Consolidation: 0.6741854636591479
