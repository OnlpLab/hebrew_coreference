# %%
% load_ext autoreload
% autoreload 2
# Out:
# UsageError: Line magic function `%` not found.

# %%
import pandas as pd
from mention_agreemnet_utils import process_annotations, read_annotation_data

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../../mention_annotation_data"

# %%
set(list(range(70, 75)))  #to fix
# Out:
# {70, 71, 72, 73, 74}

# %%
file_by_annotator = read_annotation_data(conllu_annotated_files_path, specific_files=set(list(range(70, 75))),
                                         exclude={'Shaked', 'Arbel', 'Ido', 'Yuval Sagi', 'Bar Shwarts', 'Aviv Sason'})

# %%
process_annotations(file_by_annotator)
# Out:
# 0.770637268082818

# %%
for ann in ['Itay', 'Hadar', 'Ariela']:
    for gold in ['Elisheva', 'Consolidation']:
        keys = {key: file_by_annotator[key] for key in [ann, gold] if key in file_by_annotator}

        print(f"Agreement for {ann}:{gold}: {process_annotations(keys)}")
# Out:
# Agreement for Itay:Elisheva: 0.7363896848137536
# Agreement for Itay:Consolidation: 0.6933333333333334
# Agreement for Hadar:Elisheva: 0.8788732394366198
# Agreement for Hadar:Consolidation: 0.776595744680851
# Agreement for Ariela:Elisheva: 0.8120104438642297
# Agreement for Ariela:Consolidation: 0.8320413436692506
