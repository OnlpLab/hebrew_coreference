# %%
% load_ext autoreload
% autoreload 2

# %%
import pandas as pd
from mention_agreemnet_utils import process_annotations, read_annotation_data

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../../mention_annotation_data"

# %%
set(list(range(75, 80)))  #to fix
# Out:
# {75, 76, 77, 78, 79}

# %%
file_by_annotator = read_annotation_data(conllu_annotated_files_path, specific_files=set(list(range(75, 80))),
                                         exclude={'Shaked', 'Arbel', 'Ido', 'Yuval Sagi', 'Bar Shwarts', 'Aviv Sason'})

# %%
process_annotations(file_by_annotator)
# Out:
# 0.7925595238095238

# %%
for ann in ['Itay', 'Hadar', 'Ariela', 'Elisheva']:
    for gold in ['Consolidation']:
        keys = {key: file_by_annotator[key] for key in [ann, gold] if key in file_by_annotator}

        print(f"Agreement for {ann}:{gold}: {process_annotations(keys)}")
# Out:
# Agreement for Itay:Consolidation: 0.7806122448979592
# Agreement for Hadar:Consolidation: 0.8015873015873016
# Agreement for Ariela:Consolidation: 0.7864321608040201
# Agreement for Elisheva:Consolidation: 0.7512953367875648
