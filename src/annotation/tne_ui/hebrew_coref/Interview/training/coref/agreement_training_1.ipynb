# %%
% load_ext autoreload
% autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from coref_agreement_utils import extract_name, two_annotators_agreement, n_annotators_agreement
from IPython.core.interactiveshell import InteractiveShell
from collections import defaultdict
import os

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "/Users/s0g0a87/studies/tne_ui/hebrew_coref/Interview/coref_answers/training"

# %%
files_id = set(list(range(66, 71)))
print(files_id)
file_by_annotator = defaultdict(list)
conllu_annotated_files = os.listdir(conllu_annotated_files_path)
for f in conllu_annotated_files:
    if int(f.split("_")[0]) in files_id:
        file_by_annotator[extract_name(f)].append(f)
keep_singletons = False
calc_with_mentions = False
#
# file_by_annotator = read_annotation_data(conllu_annotated_files_path, specific_files=set(list(range(65, 70))),
#                                          exclude={'Shaked', 'Arbel', 'Ido', 'Yuval Sagi', 'Bar Shwarts', 'Aviv Sason'})
# Out:
# {65, 66, 67, 68, 69}

# %%
file_by_annotator
# Out:
# defaultdict(list,
#             {'Itay': ['68_10_sents_htb_71_Itay.conllu',
#               '69_10_sents_htb_74_Itay.conllu',
#               '67_10_sents_htb_38_Itay.conllu',
#               '66_9_sents_htb_232_Itay.conllu'],
#              'Elisheva': ['66_9_sents_htb_232_Elisheva.conllu',
#               '67_10_sents_htb_38_Elisheva.conllu',
#               '69_10_sents_htb_74_Elisheva.conllu',
#               '68_10_sents_htb_71_Elisheva.conllu'],
#              'Ariela': ['67_10_sents_htb_38_Ariela.conllu',
#               '66_9_sents_htb_232_Ariela.conllu',
#               '69_10_sents_htb_74_Ariela.conllu'],
#              'Hadar': ['66_9_sents_htb_232_Hadar.conllu',
#               '69_10_sents_htb_74_Hadar.conllu',
#               '68_10_sents_htb_71_Hadar.conllu']})

# %%
agreement = {}
for ann in ['Hadar', 'Ariela', 'Itay']:
    for gold in ['Elisheva']:
        keys = {key: file_by_annotator[key] for key in [ann, gold] if key in file_by_annotator}
        print(f"{ann}:{gold}")
        agreement[f"{ann}:{gold}"] = two_annotators_agreement(ann, gold, keep_singletons, calc_with_mentions,
                                                              file_by_annotator, conllu_annotated_files_path, )
# Out:
# Hadar:Elisheva
# 37 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 92.00  Precision: 92.00  F1: 92.00
# muc        Recall: 86.67  Precision: 81.25  F1: 83.87
# bcub       Recall: 86.67  Precision: 77.40  F1: 81.77
# ceafe      Recall: 74.07  Precision: 82.30  F1: 77.97
# lea        Recall: 84.00  Precision: 72.00  F1: 77.54
# CoNLL score: 80.29
# 43 and 48 singletons are removed from the key and system files, respectively
# mentions   Recall: 70.73  Precision: 80.56  F1: 75.32
# muc        Recall: 59.26  Precision: 64.00  F1: 61.54
# bcub       Recall: 56.18  Precision: 60.58  F1: 58.30
# ceafe      Recall: 52.77  Precision: 67.16  F1: 59.10
# lea        Recall: 48.78  Precision: 52.78  F1: 50.70
# CoNLL score: 57.41
# 39 and 55 singletons are removed from the key and system files, respectively
# mentions   Recall: 73.20  Precision: 87.65  F1: 79.78
# muc        Recall: 61.54  Precision: 75.47  F1: 67.80
# bcub       Recall: 59.79  Precision: 72.78  F1: 65.65
# ceafe      Recall: 63.06  Precision: 72.06  F1: 67.26
# lea        Recall: 54.57  Precision: 67.35  F1: 60.29
# CoNLL score: 65.25
# Ariela:Elisheva
# 38 and 47 singletons are removed from the key and system files, respectively
# mentions   Recall: 44.44  Precision: 88.89  F1: 59.26
# muc        Recall: 40.00  Precision: 80.00  F1: 53.33
# bcub       Recall: 40.74  Precision: 81.48  F1: 54.32
# ceafe      Recall: 45.00  Precision: 90.00  F1: 60.00
# lea        Recall: 38.89  Precision: 77.78  F1: 51.85
# CoNLL score: 54.88
# 21 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 58.54  Precision: 96.00  F1: 72.73
# muc        Recall: 56.00  Precision: 87.50  F1: 68.29
# bcub       Recall: 53.66  Precision: 83.40  F1: 65.30
# ceafe      Recall: 51.29  Precision: 91.19  F1: 65.66
# lea        Recall: 51.22  Precision: 80.00  F1: 62.45
# CoNLL score: 65.43
# 39 and 48 singletons are removed from the key and system files, respectively
# mentions   Recall: 68.89  Precision: 86.11  F1: 76.54
# muc        Recall: 65.52  Precision: 76.00  F1: 70.37
# bcub       Recall: 59.26  Precision: 75.46  F1: 66.39
# ceafe      Recall: 54.88  Precision: 79.83  F1: 65.04
# lea        Recall: 55.56  Precision: 71.30  F1: 62.45
# CoNLL score: 66.06
# Itay:Elisheva
# 52 and 55 singletons are removed from the key and system files, respectively
# mentions   Recall: 86.90  Precision: 90.12  F1: 88.48
# muc        Recall: 76.79  Precision: 81.13  F1: 78.90
# bcub       Recall: 74.11  Precision: 80.86  F1: 77.34
# ceafe      Recall: 78.65  Precision: 78.65  F1: 78.65
# lea        Recall: 68.57  Precision: 76.82  F1: 72.46
# CoNLL score: 76.84
# 41 and 48 singletons are removed from the key and system files, respectively
# mentions   Recall: 76.74  Precision: 91.67  F1: 83.54
# muc        Recall: 71.43  Precision: 80.00  F1: 75.47
# bcub       Recall: 67.05  Precision: 81.25  F1: 73.47
# ceafe      Recall: 63.05  Precision: 85.97  F1: 72.75
# lea        Recall: 62.79  Precision: 76.85  F1: 69.11
# CoNLL score: 72.70
# 42 and 47 singletons are removed from the key and system files, respectively
# mentions   Recall: 50.00  Precision: 77.78  F1: 60.87
# muc        Recall: 50.00  Precision: 80.00  F1: 61.54
# bcub       Recall: 50.00  Precision: 77.78  F1: 60.87
# ceafe      Recall: 50.00  Precision: 75.00  F1: 60.00
# lea        Recall: 50.00  Precision: 77.78  F1: 60.87
# CoNLL score: 60.82
# 30 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 75.00  Precision: 96.00  F1: 84.21
# muc        Recall: 66.67  Precision: 75.00  F1: 70.59
# bcub       Recall: 67.19  Precision: 73.40  F1: 70.16
# ceafe      Recall: 56.29  Precision: 87.57  F1: 68.53
# lea        Recall: 62.50  Precision: 64.00  F1: 63.24
# CoNLL score: 68.13

# %%
agreement['Hadar:Elisheva']
# Out:
# {'muc': {'recall': 0.6915479582146249,
#   'precision': 0.735738993710692,
#   'f1': 0.7106867981662952},
#  'bcub': {'recall': 0.6754838336306781,
#   'precision': 0.7025326278659613,
#   'f1': 0.6857405111739},
#  'ceafe': {'recall': 0.633000734384663,
#   'precision': 0.7384362330790902,
#   'f1': 0.6811171615908459},
#  'lea': {'recall': 0.6245031151342441,
#   'precision': 0.6404343850022863,
#   'f1': 0.628434666774544}}

# %%
agreement['Itay:Elisheva']
# Out:
# {'muc': {'recall': 0.7041208791208791,
#   'precision': 0.8265498652291106,
#   'f1': 0.7567787388129721},
#  'bcub': {'recall': 0.6802816908417114,
#   'precision': 0.8184317767042405,
#   'f1': 0.7402663416982829},
#  'ceafe': {'recall': 0.6715673916031059,
#   'precision': 0.8459300487871916,
#   'f1': 0.7430759544113582},
#  'lea': {'recall': 0.6485085662171846,
#   'precision': 0.7821987236834258,
#   'f1': 0.7060908557709025}}

# %%
agreement['Ariela:Elisheva']
# Out:
# {'muc': {'recall': 0.5969749216300941,
#   'precision': 0.8516071428571428,
#   'f1': 0.695180839994054},
#  'bcub': {'recall': 0.5582782859078591,
#   'precision': 0.8406708937198069,
#   'f1': 0.6667854810465038},
#  'ceafe': {'recall': 0.5896122685185186,
#   'precision': 0.883459595959596,
#   'f1': 0.6976295529483936},
#  'lea': {'recall': 0.5329910604300848,
#   'precision': 0.8118156199677939,
#   'f1': 0.6398106106196708}}

# %%
print('Total score of "Arbel", "Ido", "Elisheva" no mentions: ')
data_no_mentions = {'f1 avg': [pd.DataFrame(ag).loc['f1'].mean() for ag in agreement.values()]}
for metric in ['muc', 'bcub', 'ceafe', 'lea']:
    data_no_mentions[metric] = [ag[metric]['f1'] for ag in agreement.values()]
df_no_mentions = pd.DataFrame(data_no_mentions, index=agreement.keys())
print(df_no_mentions['f1 avg'].mean())
# Out:
# Total score of "Arbel", "Ido", "Elisheva" no mentions:
# 0.703540514842639

# %%
pd.DataFrame(data_no_mentions, index=agreement.keys())
# Out:
#                    f1 avg       muc      bcub     ceafe       lea
# Hadar:Elisheva   0.699217  0.735396  0.696626  0.718798  0.646048
# Ariela:Elisheva  0.674852  0.695181  0.666785  0.697630  0.639811
# Itay:Elisheva    0.736553  0.756779  0.740266  0.743076  0.706091
