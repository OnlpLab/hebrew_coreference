# %%
% load_ext autoreload
% autoreload 2

# %%
from mention_agreemnet_utils import process_annotations, read_annotation_data

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../../mention_annotation_data"

# %%
docs = {8}  #to fix

# %%
file_by_annotator = read_annotation_data(conllu_annotated_files_path, specific_files=docs,
                                         exclude={'ariela levkov', 'Yeshaaya Klein', 'Hadas Elitzur', 'Nofar Eidlman',
                                                  'itay atal', 'may green', 'Shay Umaschi',
                                                  'matan schwartz', 'Tal Bacalu', 'tsofit hadad', 'Odelia Tamayev',
                                                  'Tal Chayen', 'Yovelarye', 'אוריאל אטווד', 'Tal', 'Ariela',
                                                  'shachar sasson', 'Noa Nagary', 'Shimrit Devora Laufer',
                                                  'Hadar Salniker', 'Shira Cohen', 'Ayala Dvir', 'Shali Bernstein',
                                                  'Itamar Adoram', 'yechiel hexter', 'Elisheva', 'Yuval Sagi',
                                                  'Hinoy Meirovitch', 'Yovel arye', 'hadar livyatan', 'Bar Shwarts',
                                                  'Rom Golan', 'Ido', 'Shaked', 'Aviv Sason',
                                                  })
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 file_by_annotator = read_annotation_data(conllu_annotated_files_path, specific_files=docs,
#       2                                          exclude={'ariela levkov', 'Yeshaaya Klein', 'Hadas Elitzur', 'Nofar Eidlman',
#       3                                                   'itay atal', 'may green', 'Shay Umaschi',
#       4                                                   'matan schwartz', 'Tal Bacalu', 'tsofit hadad', 'Odelia Tamayev',
#       5                                                   'Tal Chayen', 'Yovelarye', 'אוריאל אטווד', 'Tal', 'Ariela',
#       6                                                   'shachar sasson', 'Noa Nagary', 'Shimrit Devora Laufer',
#       7                                                   'Hadar Salniker', 'Shira Cohen', 'Ayala Dvir', 'Shali Bernstein',
#       8                                                   'Itamar Adoram', 'yechiel hexter', 'Elisheva', 'Yuval Sagi',
#       9                                                   'Hinoy Meirovitch', 'Yovel arye', 'hadar livyatan', 'Bar Shwarts',
#      10                                                   'Rom Golan', 'Ido', 'Shaked', 'Aviv Sason',
#      11                                                   })
#
# File ~/studies/tne_ui/hebrew_coref/Interview/training_2/mentions/mention_agreemnet_utils.py:76, in read_annotation_data(folder_path, specific_files, exclude)
#      71                     valid_spans = set([span["members"][0] for span in spans if
#      72                                        span.get("source") == "mention" or span.get("source")[0] == "mention"])
#      73                     nps = data.get("nps", [])
#      75                     annotated_spans = [(Span(np["start_index"], np["end_index"], np['text'])) for np in nps if
# ---> 76                                        np['id'] in valid_spans]
#      78                     annotations[annotation_name][hit_id] = annotated_spans
#      80 return annotations
#
# File ~/studies/tne_ui/hebrew_coref/Interview/training_2/mentions/mention_agreemnet_utils.py:76, in read_annotation_data(folder_path, specific_files, exclude)
#      71                     valid_spans = set([span["members"][0] for span in spans if
#      72                                        span.get("source") == "mention" or span.get("source")[0] == "mention"])
#      73                     nps = data.get("nps", [])
#      75                     annotated_spans = [(Span(np["start_index"], np["end_index"], np['text'])) for np in nps if
# ---> 76                                        np['id'] in valid_spans]
#      78                     annotations[annotation_name][hit_id] = annotated_spans
#      80 return annotations
#
# File _pydevd_bundle/pydevd_cython_darwin_39_64.pyx:1180, in _pydevd_bundle.pydevd_cython_darwin_39_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython_darwin_39_64.pyx:621, in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_39_64.pyx:930, in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_39_64.pyx:921, in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_39_64.pyx:318, in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.do_wait_suspend()
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1147, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1144         from_this_thread.append(frame_id)
#    1146 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1147     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1162, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1159             self._call_mpl_hook()
#    1161         self.process_internal_commands()
# -> 1162         time.sleep(0.01)
#    1164 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1166 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
file_by_annotator
# Out:
# {'Hadar': {8: [Span(start_index=7, end_index=33, text='חברת גדות תעשיות פטרוכימיה'),
#    Span(start_index=12, end_index=33, text='גדות תעשיות פטרוכימיה'),
#    Span(start_index=95, end_index=127, text='התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=121, end_index=127, text='אירופה'),
#    Span(start_index=129, end_index=144, text='הקמת המתקן החדש'),
#    Span(start_index=134, end_index=144, text='המתקן החדש'),
#    Span(start_index=174, end_index=191, text='הרחבת כושר הייצור'),
#    Span(start_index=180, end_index=191, text='כושר הייצור'),
#    Span(start_index=158, end_index=229, text='תוכנית ההשקעות להרחבת כושר הייצור, שכללה השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=199, end_index=229, text='השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=207, end_index=229, text='היקף של 02 מיליון דולר'),
#    Span(start_index=215, end_index=229, text='02 מיליון דולר'),
#    Span(start_index=231, end_index=236, text='החברה'),
#    Span(start_index=257, end_index=292, text='הפסקת ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=263, end_index=292, text='ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=278, end_index=292, text='ה_איכות הקודמת'),
#    Span(start_index=294, end_index=305, text='מנכ"ל החברה'),
#    Span(start_index=294, end_index=318, text='מנכ"ל החברה, גיורא מיוחס'),
#    Span(start_index=307, end_index=318, text='גיורא מיוחס'),
#    Span(start_index=337, end_index=341, text='_הוא'),
#    Span(start_index=381, end_index=386, text='הגומי'),
#    Span(start_index=328, end_index=394, text='תרומה_של__הוא של התהליך החדש לבריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=358, end_index=394, text='בריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=365, end_index=394, text='העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=374, end_index=394, text='תעשיות הגומי והדבקים'),
#    Span(start_index=381, end_index=394, text='הגומי והדבקים'),
#    Span(start_index=388, end_index=394, text='הדבקים'),
#    Span(start_index=24, end_index=33, text='פטרוכימיה'),
#    Span(start_index=47, end_index=127, text='מתקן הידרוגנציה לייצור ממיסים נטולי בנזן, על-פי התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=64, end_index=127, text='ייצור ממיסים נטולי בנזן, על-פי התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=83, end_index=87, text='בנזן'),
#    Span(start_index=152, end_index=229, text='מסגרת תוכנית ההשקעות להרחבת כושר הייצור, שכללה השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=345, end_index=394, text='התהליך החדש לבריאות העובדים בתעשיות הגומי והדבקים')]},
#  'Hadas': {8: [Span(start_index=7, end_index=33, text='חברת גדות תעשיות פטרוכימיה'),
#    Span(start_index=95, end_index=127, text='התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=121, end_index=127, text='אירופה'),
#    Span(start_index=337, end_index=341, text='_הוא')]},
#  'Hinoy': {8: [Span(start_index=7, end_index=33, text='חברת גדות תעשיות פטרוכימיה'),
#    Span(start_index=47, end_index=76, text='מתקן הידרוגנציה לייצור ממיסים'),
#    Span(start_index=95, end_index=127, text='התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=129, end_index=144, text='הקמת המתקן החדש'),
#    Span(start_index=134, end_index=144, text='המתקן החדש'),
#    Span(start_index=152, end_index=157, text='מסגרת'),
#    Span(start_index=180, end_index=191, text='כושר הייצור'),
#    Span(start_index=158, end_index=229, text='תוכנית ההשקעות להרחבת כושר הייצור, שכללה השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=207, end_index=229, text='היקף של 02 מיליון דולר'),
#    Span(start_index=215, end_index=229, text='02 מיליון דולר'),
#    Span(start_index=257, end_index=292, text='הפסקת ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=263, end_index=292, text='ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=278, end_index=292, text='ה_איכות הקודמת'),
#    Span(start_index=294, end_index=305, text='מנכ"ל החברה'),
#    Span(start_index=294, end_index=318, text='מנכ"ל החברה, גיורא מיוחס'),
#    Span(start_index=307, end_index=318, text='גיורא מיוחס'),
#    Span(start_index=337, end_index=341, text='_הוא'),
#    Span(start_index=345, end_index=356, text='התהליך החדש'),
#    Span(start_index=381, end_index=386, text='הגומי'),
#    Span(start_index=328, end_index=394, text='תרומה_של__הוא של התהליך החדש לבריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=358, end_index=394, text='בריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=365, end_index=394, text='העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=374, end_index=394, text='תעשיות הגומי והדבקים'),
#    Span(start_index=381, end_index=394, text='הגומי והדבקים'),
#    Span(start_index=388, end_index=394, text='הדבקים'),
#    Span(start_index=24, end_index=33, text='פטרוכימיה'),
#    Span(start_index=47, end_index=87, text='מתקן הידרוגנציה לייצור ממיסים נטולי בנזן'),
#    Span(start_index=64, end_index=88, text='ייצור ממיסים נטולי בנזן,'),
#    Span(start_index=70, end_index=87, text='ממיסים נטולי בנזן'),
#    Span(start_index=64, end_index=87, text='ייצור ממיסים נטולי בנזן'),
#    Span(start_index=47, end_index=127, text='מתקן הידרוגנציה לייצור ממיסים נטולי בנזן, על-פי התקנים המחמירים המקובלים באירופה')]},
#  'Yechiel': {8: [Span(start_index=7, end_index=33, text='חברת גדות תעשיות פטרוכימיה'),
#    Span(start_index=95, end_index=127, text='התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=121, end_index=127, text='אירופה'),
#    Span(start_index=129, end_index=144, text='הקמת המתקן החדש'),
#    Span(start_index=134, end_index=144, text='המתקן החדש'),
#    Span(start_index=174, end_index=191, text='הרחבת כושר הייצור'),
#    Span(start_index=180, end_index=191, text='כושר הייצור'),
#    Span(start_index=158, end_index=229, text='תוכנית ההשקעות להרחבת כושר הייצור, שכללה השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=199, end_index=229, text='השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=231, end_index=236, text='החברה'),
#    Span(start_index=257, end_index=292, text='הפסקת ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=263, end_index=292, text='ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=278, end_index=292, text='ה_איכות הקודמת'),
#    Span(start_index=294, end_index=305, text='מנכ"ל החברה'),
#    Span(start_index=294, end_index=318, text='מנכ"ל החברה, גיורא מיוחס'),
#    Span(start_index=307, end_index=318, text='גיורא מיוחס'),
#    Span(start_index=337, end_index=341, text='_הוא'),
#    Span(start_index=345, end_index=356, text='התהליך החדש'),
#    Span(start_index=381, end_index=386, text='הגומי'),
#    Span(start_index=328, end_index=394, text='תרומה_של__הוא של התהליך החדש לבריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=358, end_index=394, text='בריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=365, end_index=394, text='העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=374, end_index=394, text='תעשיות הגומי והדבקים'),
#    Span(start_index=381, end_index=394, text='הגומי והדבקים'),
#    Span(start_index=388, end_index=394, text='הדבקים'),
#    Span(start_index=47, end_index=87, text='מתקן הידרוגנציה לייצור ממיסים נטולי בנזן'),
#    Span(start_index=64, end_index=87, text='ייצור ממיסים נטולי בנזן'),
#    Span(start_index=70, end_index=87, text='ממיסים נטולי בנזן'),
#    Span(start_index=83, end_index=87, text='בנזן'),
#    Span(start_index=152, end_index=229, text='מסגרת תוכנית ההשקעות להרחבת כושר הייצור, שכללה השקעות בהיקף של 02 מיליון דולר')]},
#  'Itay': {8: [Span(start_index=7, end_index=33, text='חברת גדות תעשיות פטרוכימיה'),
#    Span(start_index=95, end_index=127, text='התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=121, end_index=127, text='אירופה'),
#    Span(start_index=129, end_index=144, text='הקמת המתקן החדש'),
#    Span(start_index=134, end_index=144, text='המתקן החדש'),
#    Span(start_index=152, end_index=157, text='מסגרת'),
#    Span(start_index=174, end_index=191, text='הרחבת כושר הייצור'),
#    Span(start_index=180, end_index=191, text='כושר הייצור'),
#    Span(start_index=199, end_index=229, text='השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=207, end_index=229, text='היקף של 02 מיליון דולר'),
#    Span(start_index=215, end_index=229, text='02 מיליון דולר'),
#    Span(start_index=231, end_index=236, text='החברה'),
#    Span(start_index=263, end_index=292, text='ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=278, end_index=292, text='ה_איכות הקודמת'),
#    Span(start_index=294, end_index=305, text='מנכ"ל החברה'),
#    Span(start_index=294, end_index=318, text='מנכ"ל החברה, גיורא מיוחס'),
#    Span(start_index=307, end_index=318, text='גיורא מיוחס'),
#    Span(start_index=337, end_index=341, text='_הוא'),
#    Span(start_index=345, end_index=356, text='התהליך החדש'),
#    Span(start_index=381, end_index=386, text='הגומי'),
#    Span(start_index=328, end_index=394, text='תרומה_של__הוא של התהליך החדש לבריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=358, end_index=394, text='בריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=365, end_index=394, text='העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=374, end_index=394, text='תעשיות הגומי והדבקים'),
#    Span(start_index=381, end_index=394, text='הגומי והדבקים'),
#    Span(start_index=388, end_index=394, text='הדבקים'),
#    Span(start_index=47, end_index=127, text='מתקן הידרוגנציה לייצור ממיסים נטולי בנזן, על-פי התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=64, end_index=127, text='ייצור ממיסים נטולי בנזן, על-פי התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=70, end_index=87, text='ממיסים נטולי בנזן'),
#    Span(start_index=269, end_index=292, text='הממיסים בה_איכות הקודמת')]},
#  'Consolidation': {8: [Span(start_index=7, end_index=33, text='חברת גדות תעשיות פטרוכימיה'),
#    Span(start_index=12, end_index=33, text='גדות תעשיות פטרוכימיה'),
#    Span(start_index=24, end_index=33, text='פטרוכימיה'),
#    Span(start_index=47, end_index=127, text='מתקן הידרוגנציה לייצור ממיסים נטולי בנזן, על-פי התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=64, end_index=127, text='ייצור ממיסים נטולי בנזן, על-פי התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=70, end_index=87, text='ממיסים נטולי בנזן'),
#    Span(start_index=83, end_index=87, text='בנזן'),
#    Span(start_index=95, end_index=127, text='התקנים המחמירים המקובלים באירופה'),
#    Span(start_index=121, end_index=127, text='אירופה'),
#    Span(start_index=129, end_index=144, text='הקמת המתקן החדש'),
#    Span(start_index=134, end_index=144, text='המתקן החדש'),
#    Span(start_index=152, end_index=229, text='מסגרת תוכנית ההשקעות להרחבת כושר הייצור, שכללה השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=158, end_index=229, text='תוכנית ההשקעות להרחבת כושר הייצור, שכללה השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=174, end_index=191, text='הרחבת כושר הייצור'),
#    Span(start_index=180, end_index=191, text='כושר הייצור'),
#    Span(start_index=199, end_index=229, text='השקעות בהיקף של 02 מיליון דולר'),
#    Span(start_index=215, end_index=229, text='02 מיליון דולר'),
#    Span(start_index=231, end_index=236, text='החברה'),
#    Span(start_index=257, end_index=292, text='הפסקת ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=263, end_index=292, text='ייצור הממיסים בה_איכות הקודמת'),
#    Span(start_index=269, end_index=292, text='הממיסים בה_איכות הקודמת'),
#    Span(start_index=278, end_index=292, text='ה_איכות הקודמת'),
#    Span(start_index=294, end_index=305, text='מנכ"ל החברה'),
#    Span(start_index=294, end_index=318, text='מנכ"ל החברה, גיורא מיוחס'),
#    Span(start_index=307, end_index=318, text='גיורא מיוחס'),
#    Span(start_index=328, end_index=394, text='תרומה_של__הוא של התהליך החדש לבריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=337, end_index=341, text='_הוא'),
#    Span(start_index=345, end_index=356, text='התהליך החדש'),
#    Span(start_index=345, end_index=394, text='התהליך החדש לבריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=358, end_index=394, text='בריאות העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=365, end_index=394, text='העובדים בתעשיות הגומי והדבקים'),
#    Span(start_index=374, end_index=394, text='תעשיות הגומי והדבקים'),
#    Span(start_index=381, end_index=394, text='הגומי והדבקים')]},
#  'Arbel': {}}

# %%
process_annotations(file_by_annotator)
# Out:
# 0.5666666666666667

# %%
for ann in ['Hadas', 'Hinoy', 'Yechiel']:
    for gold in ['Hadar', 'Consolidation']:
        keys = {key: file_by_annotator[key] for key in [ann, gold] if key in file_by_annotator}
        print(f"Agreement for {ann}:{gold}: {process_annotations(keys)}")
# Out:
# Agreement for Hadas:Hadar: 0.12121212121212122
# Agreement for Hadas:Consolidation: 0.12121212121212122
# Agreement for Hinoy:Hadar: 0.7272727272727273
# Agreement for Hinoy:Consolidation: 0.696969696969697
# Agreement for Yechiel:Hadar: 0.7878787878787878
# Agreement for Yechiel:Consolidation: 0.7878787878787878
