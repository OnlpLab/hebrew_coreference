# %%
% load_ext autoreload
% autoreload 2

# %%
from mention_agreemnet_utils import process_annotations, read_annotation_data

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
test_files = "mention_answers"

# %%
file_by_annotator = read_annotation_data(test_files, exclude={'Shaked', 'Consolidation'})

# %%
process_annotations(file_by_annotator)
# Out:
# 0.7042301646962346

# %%
file_by_annotator.keys()
# Out:
# dict_keys(['ariela levkov', 'Yeshaaya Klein', 'Bar Shwarts', 'itay atal', 'Tal Bacalu', 'Tal Chayen', 'אוריאל אטווד', 'shachar sasson', 'Noa Nagary', 'gold', 'Ayala Dvir', 'Aviv Sason', 'Yuval Sagi', 'hadar livyatan', 'Rom Golan'])

# %%
scores = []
for k, v in file_by_annotator.items():
    if k == "gold":
        continue

    test = {key: file_by_annotator[key] for key in {"gold", k} if key in file_by_annotator}
    scores.append((k, process_annotations(test)))

scores.sort(key=lambda x: x[1])
for name, score in scores:
    print(f"score for {name}: {score}")
# Out:
# score for Rom Golan: 0.5743243243243243
# score for Noa Nagary: 0.5878378378378378
# score for אוריאל אטווד: 0.6
# score for Bar Shwarts: 0.7162162162162162
# score for Aviv Sason: 0.7162162162162162
# score for Yeshaaya Klein: 0.7297297297297297
# score for Ayala Dvir: 0.7712765957446809
# score for hadar livyatan: 0.7909604519774012
# score for Tal Bacalu: 0.8040540540540541
# score for itay atal: 0.8120805369127517
# score for shachar sasson: 0.8187919463087249
# score for ariela levkov: 0.8282208588957055
# score for Yuval Sagi: 0.8311688311688312
# score for Tal Chayen: 0.8648648648648649

# %%
for k, v in file_by_annotator.items():
    if k == "gold":
        continue

    test = {key: file_by_annotator[key] for key in {"gold", k} if key in file_by_annotator}
    print(f"score for {k}")
    print(process_annotations(test, to_print=True))
# Out:
# score for ariela levkov
# 60
# Disagreement
# Only in gold:
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=207, end_index=213, text='התכנון')
# Span(start_index=81, end_index=108, text='עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=8, end_index=19, text='אחר-הצהריים')
# Only in ariela levkov:
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=516, end_index=528, text='תקופה ממושכת')
# Span(start_index=12, end_index=19, text='הצהריים')
# Span(start_index=494, end_index=500, text='חומרים')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=550, end_index=561, text='שעות ארוכות')
# 10
# Disagreement
# Only in gold:
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=201, end_index=213, text='טענת שבראווי')
# Span(start_index=140, end_index=152, text='החברה המצרית')
# Span(start_index=89, end_index=101, text='מחלוקת כספית')
# Span(start_index=386, end_index=422, text='מנכ"ל חברת טיולי הגליל, עזרא בן דורי')
# Span(start_index=430, end_index=440, text='צד_של__הוא')
# Span(start_index=415, end_index=422, text='בן דורי')
# Only in ariela levkov:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=186, end_index=198, text='601,016 דולר')
# Span(start_index=36, end_index=53, text='נשיא חברת התיירות')
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=127, end_index=138, text='טיולי הגליל')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=30, end_index=35, text='פיתוח')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=298, end_index=305, text='התעשייה')
# Span(start_index=462, end_index=466, text='_הוא')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=178, end_index=185, text='ירושלים')
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=147, end_index=151, text='מו"ף')
# Span(start_index=113, end_index=185, text='מועצת המנהלים של הקרן הדו-לאומית למו"ף ישראל-ארה"ב שתתכנס השבוע בירושלים')
# Span(start_index=279, end_index=284, text='ה_קרן')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Only in ariela levkov:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=8, end_index=35, text='פרויקטים חדשים במחקר ופיתוח')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=307, end_index=312, text='האוצר')
# Span(start_index=652, end_index=663, text='מחקר ופיתוח')
# Span(start_index=472, end_index=480, text='עדיפויות')
# Span(start_index=50, end_index=67, text='שמונה מיליון דולר')
# Span(start_index=576, end_index=584, text='המצטברות')
# Span(start_index=8, end_index=22, text='פרויקטים חדשים')
# Span(start_index=112, end_index=163, text='למועצת המנהלים של הקרן הדו-לאומית למו"ף ישראל-ארה"ב')
# Span(start_index=595, end_index=604, text='עזרת הקרן')
# Span(start_index=717, end_index=731, text='30 מיליון דולר')
# Span(start_index=840, end_index=855, text='110 מיליון דולר')
# Span(start_index=766, end_index=788, text='מימון פרויקטים משותפים')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=829, end_index=838, text='סכום הקרן')
# Span(start_index=606, end_index=618, text='ה_סכום הקרוב')
# Span(start_index=586, end_index=593, text='פיתוחים')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=378, end_index=391, text='התעשייה, החוץ')
# 0.7721518987341772
# score for Yeshaaya Klein
# 60
# Disagreement
# Only in gold:
# Span(start_index=199, end_index=205, text='העיצוב')
# Span(start_index=440, end_index=443, text='_הם')
# Span(start_index=199, end_index=213, text='העיצוב והתכנון')
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=275, end_index=280, text='אפקוט')
# Span(start_index=445, end_index=450, text='ה_שטח')
# Span(start_index=468, end_index=472, text='ה_זה')
# Span(start_index=207, end_index=213, text='התכנון')
# Span(start_index=81, end_index=108, text='עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=452, end_index=472, text='השתתפות בסמינר כה_זה')
# Span(start_index=295, end_index=299, text='ציור')
# Span(start_index=240, end_index=256, text='אוניברסיטת דיסני')
# Span(start_index=139, end_index=144, text='המקום')
# Span(start_index=270, end_index=273, text='מסע')
# Span(start_index=303, end_index=308, text='רישום')
# Only in Yeshaaya Klein:
# Span(start_index=576, end_index=586, text='אתרי הנופש')
# Span(start_index=150, end_index=153, text='אחר')
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=356, end_index=360, text='ימים')
# Span(start_index=494, end_index=500, text='חומרים')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=65, end_index=108, text='אחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=550, end_index=561, text='שעות ארוכות')
# 10
# Disagreement
# Only in gold:
# Span(start_index=355, end_index=385, text='התפתחות_של__היא של תקרית מביכה')
# Span(start_index=201, end_index=213, text='טענת שבראווי')
# Span(start_index=366, end_index=370, text='_היא')
# Span(start_index=441, end_index=464, text='נכונות לסיים את המחלוקת')
# Span(start_index=288, end_index=292, text='קהיר')
# Span(start_index=8, end_index=12, text='היום')
# Span(start_index=140, end_index=152, text='החברה המצרית')
# Span(start_index=386, end_index=422, text='מנכ"ל חברת טיולי הגליל, עזרא בן דורי')
# Span(start_index=430, end_index=440, text='צד_של__הוא')
# Span(start_index=410, end_index=422, text='עזרא בן דורי')
# Span(start_index=457, end_index=464, text='המחלוקת')
# Span(start_index=36, end_index=77, text='נשיא חברת התיירות אמין טורס, אמין שבראווי')
# Span(start_index=246, end_index=250, text='החוב')
# Span(start_index=374, end_index=385, text='תקרית מביכה')
# Span(start_index=89, end_index=101, text='מחלוקת כספית')
# Span(start_index=294, end_index=302, text='השגרירות')
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=221, end_index=250, text='כל מאמץ_של__הוא לגבות את החוב')
# Span(start_index=65, end_index=77, text='אמין שבראווי')
# Span(start_index=333, end_index=343, text='עניין החוב')
# Span(start_index=232, end_index=236, text='_הוא')
# Span(start_index=256, end_index=262, text='ה_תוהו')
# Span(start_index=273, end_index=292, text='שגרירות ישראל בקהיר')
# Span(start_index=415, end_index=422, text='בן דורי')
# Span(start_index=264, end_index=267, text='הוא')
# Span(start_index=397, end_index=408, text='טיולי הגליל')
# Span(start_index=41, end_index=63, text='חברת התיירות אמין טורס')
# Span(start_index=30, end_index=35, text='מצרים')
# Span(start_index=324, end_index=331, text='ירושלים')
# Span(start_index=105, end_index=138, text='חברת התיירות הישראלית טיולי הגליל')
# Span(start_index=386, end_index=408, text='מנכ"ל חברת טיולי הגליל')
# Span(start_index=392, end_index=408, text='חברת טיולי הגליל')
# Only in Yeshaaya Klein:
# Span(start_index=36, end_index=63, text='נשיא חברת התיירות אמין טורס')
# 64
# Disagreement
# Only in gold:
# Span(start_index=298, end_index=312, text='התעשייה והאוצר')
# Span(start_index=343, end_index=348, text='המסחר')
# Span(start_index=652, end_index=656, text='מחקר')
# Span(start_index=171, end_index=176, text='השבוע')
# Span(start_index=334, end_index=341, text='התעשייה')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=802, end_index=808, text='הפיתוח')
# Span(start_index=811, end_index=821, text='מרוצת הזמן')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=158, end_index=163, text='ארה"ב')
# Span(start_index=697, end_index=709, text='ארה"ב וישראל')
# Span(start_index=658, end_index=663, text='פיתוח')
# Span(start_index=373, end_index=391, text='משרד התעשייה, החוץ')
# Span(start_index=130, end_index=163, text='הקרן הדו-לאומית למו"ף ישראל-ארה"ב')
# Span(start_index=279, end_index=284, text='ה_קרן')
# Span(start_index=334, end_index=348, text='התעשייה והמסחר')
# Span(start_index=462, end_index=466, text='_הוא')
# Span(start_index=314, end_index=348, text='המדען הראשי של משרד התעשייה והמסחר')
# Span(start_index=30, end_index=35, text='פיתוח')
# Span(start_index=503, end_index=508, text='פעולה')
# Span(start_index=298, end_index=305, text='התעשייה')
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=378, end_index=385, text='התעשייה')
# Only in Yeshaaya Klein:
# Span(start_index=373, end_index=385, text='משרד התעשייה')
# Span(start_index=281, end_index=312, text='קרן מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=671, end_index=679, text='שנת 1977')
# Span(start_index=50, end_index=67, text='שמונה מיליון דולר')
# Span(start_index=586, end_index=593, text='פיתוחים')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=595, end_index=604, text='עזרת הקרן')
# Span(start_index=606, end_index=618, text='ה_סכום הקרוב')
# Span(start_index=829, end_index=838, text='סכום הקרן')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=840, end_index=855, text='110 מיליון דולר')
# 0.496551724137931
# score for Bar Shwarts
# 60
# Disagreement
# Only in gold:
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=479, end_index=487, text='586 דולר')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=193, end_index=213, text='עובדי העיצוב והתכנון')
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=158, end_index=164, text='הילדים')
# Span(start_index=445, end_index=450, text='ה_שטח')
# Span(start_index=468, end_index=472, text='ה_זה')
# Span(start_index=8, end_index=19, text='אחר-הצהריים')
# Span(start_index=207, end_index=213, text='התכנון')
# Span(start_index=81, end_index=108, text='עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=570, end_index=595, text='עשרות אתרי הנופש בה_סביבה')
# Span(start_index=240, end_index=256, text='אוניברסיטת דיסני')
# Span(start_index=270, end_index=273, text='מסע')
# Span(start_index=303, end_index=308, text='רישום')
# Only in Bar Shwarts:
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=516, end_index=528, text='תקופה ממושכת')
# Span(start_index=541, end_index=548, text='הצעירים')
# 10
# Disagreement
# Only in gold:
# Span(start_index=355, end_index=385, text='התפתחות_של__היא של תקרית מביכה')
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=201, end_index=213, text='טענת שבראווי')
# Span(start_index=457, end_index=464, text='המחלוקת')
# Span(start_index=366, end_index=370, text='_היא')
# Span(start_index=264, end_index=267, text='הוא')
# Span(start_index=374, end_index=385, text='תקרית מביכה')
# Span(start_index=386, end_index=408, text='מנכ"ל חברת טיולי הגליל')
# Span(start_index=256, end_index=262, text='ה_תוהו')
# Span(start_index=294, end_index=302, text='השגרירות')
# Span(start_index=273, end_index=292, text='שגרירות ישראל בקהיר')
# Only in Bar Shwarts:
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=54, end_index=63, text='אמין טורס')
# Span(start_index=127, end_index=138, text='טיולי הגליל')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=790, end_index=808, text='תחום המחקר והפיתוח')
# Span(start_index=652, end_index=656, text='מחקר')
# Span(start_index=171, end_index=176, text='השבוע')
# Span(start_index=635, end_index=663, text='הקרן הדו-לאומית למחקר ופיתוח')
# Span(start_index=482, end_index=549, text='פרויקטים ב_הם משתפות פעולה חברות אמריקאיות חדשות, עם חברות ישראליות')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=373, end_index=414, text='משרד התעשייה, החוץ, ומכון התקנים האמריקאי')
# Span(start_index=811, end_index=821, text='מרוצת הזמן')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=373, end_index=391, text='משרד התעשייה, החוץ')
# Span(start_index=772, end_index=808, text='פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=130, end_index=163, text='הקרן הדו-לאומית למו"ף ישראל-ארה"ב')
# Span(start_index=24, end_index=28, text='מחקר')
# Span(start_index=568, end_index=604, text='המכירות המצטברות מפיתוחים בעזרת הקרן')
# Span(start_index=329, end_index=348, text='משרד התעשייה והמסחר')
# Span(start_index=334, end_index=348, text='התעשייה והמסחר')
# Span(start_index=187, end_index=196, text='הפרויקטים')
# Span(start_index=314, end_index=348, text='המדען הראשי של משרד התעשייה והמסחר')
# Span(start_index=394, end_index=414, text='מכון התקנים האמריקאי')
# Span(start_index=697, end_index=702, text='ארה"ב')
# Span(start_index=178, end_index=185, text='ירושלים')
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=378, end_index=385, text='התעשייה')
# Span(start_index=264, end_index=269, text='ישראל')
# Span(start_index=752, end_index=758, text='ההשקעה')
# Span(start_index=285, end_index=348, text='מנכ"לי משרדי התעשייה והאוצר והמדען הראשי של משרד התעשייה והמסחר')
# Only in Bar Shwarts:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=766, end_index=808, text='מימון פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=472, end_index=480, text='עדיפויות')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=576, end_index=584, text='המצטברות')
# Span(start_index=586, end_index=593, text='פיתוחים')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=606, end_index=618, text='ה_סכום הקרוב')
# Span(start_index=717, end_index=731, text='30 מיליון דולר')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# 0.6344827586206897
# score for itay atal
# 60
# Disagreement
# Only in gold:
# Span(start_index=199, end_index=205, text='העיצוב')
# Span(start_index=461, end_index=472, text='סמינר כה_זה')
# Span(start_index=199, end_index=213, text='העיצוב והתכנון')
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=479, end_index=487, text='586 דולר')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=21, end_index=29, text='המשתתפים')
# Span(start_index=303, end_index=308, text='רישום')
# Span(start_index=207, end_index=213, text='התכנון')
# Span(start_index=282, end_index=308, text='עבודה מעשית בציור או רישום')
# Span(start_index=470, end_index=472, text='זה')
# Span(start_index=8, end_index=19, text='אחר-הצהריים')
# Span(start_index=295, end_index=308, text='ציור או רישום')
# Only in itay atal:
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=12, end_index=19, text='הצהריים')
# Span(start_index=356, end_index=360, text='ימים')
# Span(start_index=503, end_index=528, text='הורים הבאים לתקופה ממושכת')
# Span(start_index=494, end_index=500, text='חומרים')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=550, end_index=561, text='שעות ארוכות')
# 10
# Disagreement
# Only in gold:
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=221, end_index=250, text='כל מאמץ_של__הוא לגבות את החוב')
# Span(start_index=256, end_index=262, text='ה_תוהו')
# Span(start_index=430, end_index=440, text='צד_של__הוא')
# Span(start_index=415, end_index=422, text='בן דורי')
# Only in itay atal:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=41, end_index=53, text='חברת התיירות')
# Span(start_index=54, end_index=63, text='אמין טורס')
# Span(start_index=36, end_index=53, text='נשיא חברת התיירות')
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=127, end_index=138, text='טיולי הגליל')
# Span(start_index=436, end_index=440, text='_הוא')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=298, end_index=312, text='התעשייה והאוצר')
# Span(start_index=171, end_index=176, text='השבוע')
# Span(start_index=334, end_index=341, text='התעשייה')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=802, end_index=808, text='הפיתוח')
# Span(start_index=704, end_index=709, text='ישראל')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=292, end_index=312, text='משרדי התעשייה והאוצר')
# Span(start_index=130, end_index=163, text='הקרן הדו-לאומית למו"ף ישראל-ארה"ב')
# Span(start_index=568, end_index=604, text='המכירות המצטברות מפיתוחים בעזרת הקרן')
# Span(start_index=24, end_index=28, text='מחקר')
# Span(start_index=279, end_index=284, text='ה_קרן')
# Span(start_index=24, end_index=35, text='מחקר ופיתוח')
# Span(start_index=248, end_index=259, text='מערכות בקרה')
# Span(start_index=113, end_index=185, text='מועצת המנהלים של הקרן הדו-לאומית למו"ף ישראל-ארה"ב שתתכנס השבוע בירושלים')
# Span(start_index=30, end_index=35, text='פיתוח')
# Span(start_index=298, end_index=305, text='התעשייה')
# Span(start_index=152, end_index=163, text='ישראל-ארה"ב')
# Span(start_index=285, end_index=305, text='מנכ"לי משרדי התעשייה')
# Span(start_index=264, end_index=269, text='ישראל')
# Span(start_index=147, end_index=151, text='מו"ף')
# Span(start_index=752, end_index=758, text='ההשקעה')
# Span(start_index=285, end_index=348, text='מנכ"לי משרדי התעשייה והאוצר והמדען הראשי של משרד התעשייה והמסחר')
# Only in itay atal:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=766, end_index=808, text='מימון פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=472, end_index=480, text='עדיפויות')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=307, end_index=312, text='האוצר')
# Span(start_index=576, end_index=584, text='המצטברות')
# Span(start_index=586, end_index=593, text='פיתוחים')
# Span(start_index=829, end_index=838, text='סכום הקרן')
# Span(start_index=595, end_index=604, text='עזרת הקרן')
# Span(start_index=652, end_index=663, text='מחקר ופיתוח')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=378, end_index=391, text='התעשייה, החוץ')
# Span(start_index=840, end_index=855, text='110 מיליון דולר')
# 0.6845637583892618
# score for Tal Chayen
# 60
# Disagreement
# Only in gold:
# Span(start_index=199, end_index=205, text='העיצוב')
# Span(start_index=199, end_index=213, text='העיצוב והתכנון')
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=479, end_index=487, text='586 דולר')
# Span(start_index=433, end_index=443, text='חלק_של__הם')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=468, end_index=472, text='ה_זה')
# Span(start_index=207, end_index=213, text='התכנון')
# Span(start_index=8, end_index=19, text='אחר-הצהריים')
# Span(start_index=295, end_index=308, text='ציור או רישום')
# Only in Tal Chayen:
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=516, end_index=528, text='תקופה ממושכת')
# Span(start_index=503, end_index=528, text='הורים הבאים לתקופה ממושכת')
# Span(start_index=494, end_index=500, text='חומרים')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=550, end_index=561, text='שעות ארוכות')
# 10
# Disagreement
# Only in gold:
# Span(start_index=264, end_index=267, text='הוא')
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=201, end_index=213, text='טענת שבראווי')
# Span(start_index=41, end_index=63, text='חברת התיירות אמין טורס')
# Span(start_index=221, end_index=250, text='כל מאמץ_של__הוא לגבות את החוב')
# Span(start_index=386, end_index=408, text='מנכ"ל חברת טיולי הגליל')
# Span(start_index=392, end_index=408, text='חברת טיולי הגליל')
# Span(start_index=232, end_index=236, text='_הוא')
# Span(start_index=273, end_index=292, text='שגרירות ישראל בקהיר')
# Only in Tal Chayen:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=186, end_index=198, text='601,016 דולר')
# Span(start_index=54, end_index=63, text='אמין טורס')
# Span(start_index=127, end_index=138, text='טיולי הגליל')
# Span(start_index=436, end_index=440, text='_הוא')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# 64
# Disagreement
# Only in gold:
# Span(start_index=298, end_index=312, text='התעשייה והאוצר')
# Span(start_index=343, end_index=348, text='המסחר')
# Span(start_index=652, end_index=656, text='מחקר')
# Span(start_index=334, end_index=341, text='התעשייה')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=733, end_index=738, text='ה_קרן')
# Span(start_index=158, end_index=163, text='ארה"ב')
# Span(start_index=373, end_index=391, text='משרד התעשייה, החוץ')
# Span(start_index=334, end_index=348, text='התעשייה והמסחר')
# Span(start_index=387, end_index=391, text='החוץ')
# Span(start_index=462, end_index=466, text='_הוא')
# Span(start_index=201, end_index=259, text='תחומי אלקטרוניקה, מחשבים, תוכנה, טלקומוניקציה ומערכות בקרה')
# Span(start_index=298, end_index=305, text='התעשייה')
# Span(start_index=152, end_index=163, text='ישראל-ארה"ב')
# Span(start_index=285, end_index=305, text='מנכ"לי משרדי התעשייה')
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=378, end_index=385, text='התעשייה')
# Span(start_index=147, end_index=151, text='מו"ף')
# Only in Tal Chayen:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=472, end_index=480, text='עדיפויות')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=671, end_index=679, text='שנת 1977')
# Span(start_index=576, end_index=584, text='המצטברות')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=829, end_index=838, text='סכום הקרן')
# Span(start_index=595, end_index=604, text='עזרת הקרן')
# Span(start_index=652, end_index=663, text='מחקר ופיתוח')
# Span(start_index=717, end_index=731, text='30 מיליון דולר')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=840, end_index=855, text='110 מיליון דולר')
# 0.7241379310344828
# score for אוריאל אטווד
# 10
# Disagreement
# Only in gold:
# Span(start_index=355, end_index=385, text='התפתחות_של__היא של תקרית מביכה')
# Span(start_index=410, end_index=422, text='עזרא בן דורי')
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=457, end_index=464, text='המחלוקת')
# Span(start_index=415, end_index=422, text='בן דורי')
# Span(start_index=246, end_index=250, text='החוב')
# Span(start_index=397, end_index=408, text='טיולי הגליל')
# Span(start_index=140, end_index=152, text='החברה המצרית')
# Span(start_index=105, end_index=138, text='חברת התיירות הישראלית טיולי הגליל')
# Span(start_index=392, end_index=408, text='חברת טיולי הגליל')
# Span(start_index=89, end_index=101, text='מחלוקת כספית')
# Span(start_index=294, end_index=302, text='השגרירות')
# Span(start_index=273, end_index=292, text='שגרירות ישראל בקהיר')
# Only in אוריאל אטווד:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=41, end_index=53, text='חברת התיירות')
# Span(start_index=54, end_index=63, text='אמין טורס')
# Span(start_index=36, end_index=53, text='נשיא חברת התיירות')
# Span(start_index=436, end_index=440, text='_הוא')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 0.59375
# score for Noa Nagary
# 60
# Disagreement
# Only in gold:
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=282, end_index=308, text='עבודה מעשית בציור או רישום')
# Span(start_index=416, end_index=421, text='המקום')
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=479, end_index=487, text='586 דולר')
# Span(start_index=81, end_index=94, text='עיצוב המשטחים')
# Span(start_index=152, end_index=156, text='ה_חי')
# Span(start_index=400, end_index=421, text='סודות הניהול של המקום')
# Span(start_index=433, end_index=443, text='חלק_של__הם')
# Span(start_index=369, end_index=380, text='הכרת הסביבה')
# Span(start_index=598, end_index=607, text='בית המלון')
# Span(start_index=310, end_index=333, text='סמינר ממושך מקצועי יותר')
# Span(start_index=207, end_index=213, text='התכנון')
# Span(start_index=81, end_index=108, text='עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=570, end_index=595, text='עשרות אתרי הנופש בה_סביבה')
# Span(start_index=139, end_index=144, text='המקום')
# Span(start_index=440, end_index=443, text='_הם')
# Span(start_index=199, end_index=213, text='העיצוב והתכנון')
# Span(start_index=270, end_index=308, text='מסע לאפקוט ועבודה מעשית בציור או רישום')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=127, end_index=144, text='ה_צמחייה של המקום')
# Span(start_index=8, end_index=19, text='אחר-הצהריים')
# Span(start_index=275, end_index=280, text='אפקוט')
# Span(start_index=445, end_index=450, text='ה_שטח')
# Span(start_index=468, end_index=472, text='ה_זה')
# Span(start_index=470, end_index=472, text='זה')
# Span(start_index=240, end_index=256, text='אוניברסיטת דיסני')
# Span(start_index=270, end_index=273, text='מסע')
# Span(start_index=96, end_index=108, text='תכנון הסביבה')
# Only in Noa Nagary:
# Span(start_index=571, end_index=586, text='שרות אתרי הנופש')
# Span(start_index=576, end_index=586, text='אתרי הנופש')
# Span(start_index=570, end_index=586, text='עשרות אתרי הנופש')
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=12, end_index=19, text='הצהריים')
# Span(start_index=356, end_index=360, text='ימים')
# Span(start_index=176, end_index=188, text='פעילות היומי')
# Span(start_index=437, end_index=443, text='של__הם')
# Span(start_index=503, end_index=508, text='הורים')
# Span(start_index=549, end_index=554, text='לשעות')
# 10
# Disagreement
# Only in gold:
# Span(start_index=355, end_index=385, text='התפתחות_של__היא של תקרית מביכה')
# Span(start_index=264, end_index=267, text='הוא')
# Span(start_index=397, end_index=408, text='טיולי הגליל')
# Span(start_index=457, end_index=464, text='המחלוקת')
# Span(start_index=246, end_index=250, text='החוב')
# Span(start_index=41, end_index=63, text='חברת התיירות אמין טורס')
# Span(start_index=374, end_index=385, text='תקרית מביכה')
# Span(start_index=441, end_index=464, text='נכונות לסיים את המחלוקת')
# Span(start_index=288, end_index=292, text='קהיר')
# Span(start_index=221, end_index=250, text='כל מאמץ_של__הוא לגבות את החוב')
# Span(start_index=65, end_index=77, text='אמין שבראווי')
# Span(start_index=392, end_index=408, text='חברת טיולי הגליל')
# Only in Noa Nagary:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=186, end_index=198, text='601,016 דולר')
# Span(start_index=41, end_index=53, text='חברת התיירות')
# Span(start_index=36, end_index=53, text='נשיא חברת התיירות')
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=436, end_index=440, text='_הוא')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# Span(start_index=36, end_index=63, text='נשיא חברת התיירות אמין טורס')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=298, end_index=312, text='התעשייה והאוצר')
# Span(start_index=790, end_index=808, text='תחום המחקר והפיתוח')
# Span(start_index=343, end_index=348, text='המסחר')
# Span(start_index=334, end_index=341, text='התעשייה')
# Span(start_index=432, end_index=444, text='משרד התעשייה')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=811, end_index=821, text='מרוצת הזמן')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=733, end_index=738, text='ה_קרן')
# Span(start_index=373, end_index=391, text='משרד התעשייה, החוץ')
# Span(start_index=772, end_index=808, text='פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=37, end_index=67, text='היקף כולל של שמונה מיליון דולר')
# Span(start_index=334, end_index=348, text='התעשייה והמסחר')
# Span(start_index=387, end_index=391, text='החוץ')
# Span(start_index=8, end_index=104, text='פרויקטים חדשים במחקר ופיתוח בהיקף כולל של שמונה מיליון דולר, המשותפים לחברות ישראליות ואמריקאיות')
# Span(start_index=462, end_index=466, text='_הוא')
# Span(start_index=187, end_index=196, text='הפרויקטים')
# Span(start_index=113, end_index=185, text='מועצת המנהלים של הקרן הדו-לאומית למו"ף ישראל-ארה"ב שתתכנס השבוע בירושלים')
# Span(start_index=503, end_index=508, text='פעולה')
# Span(start_index=298, end_index=305, text='התעשייה')
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=378, end_index=385, text='התעשייה')
# Span(start_index=147, end_index=151, text='מו"ף')
# Span(start_index=752, end_index=758, text='ההשקעה')
# Only in Noa Nagary:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=187, end_index=259, text='הפרויקטים הם בתחומי אלקטרוניקה, מחשבים, תוכנה, טלקומוניקציה ומערכות בקרה')
# Span(start_index=671, end_index=679, text='שנת 1977')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=606, end_index=618, text='ה_סכום הקרוב')
# Span(start_index=652, end_index=663, text='מחקר ופיתוח')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=568, end_index=584, text='המכירות המצטברות')
# 0.5448275862068965
# score for Ayala Dvir
# 60
# Disagreement
# Only in gold:
# Span(start_index=199, end_index=213, text='העיצוב והתכנון')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=468, end_index=472, text='ה_זה')
# Span(start_index=470, end_index=472, text='זה')
# Only in Ayala Dvir:
# Span(start_index=576, end_index=586, text='אתרי הנופש')
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=110, end_index=115, text='סמינר')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=516, end_index=528, text='תקופה ממושכת')
# Span(start_index=356, end_index=360, text='ימים')
# Span(start_index=503, end_index=528, text='הורים הבאים לתקופה ממושכת')
# Span(start_index=483, end_index=487, text='דולר')
# Span(start_index=503, end_index=508, text='הורים')
# Span(start_index=494, end_index=500, text='חומרים')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=550, end_index=561, text='שעות ארוכות')
# 10
# Disagreement
# Only in gold:
# Span(start_index=397, end_index=408, text='טיולי הגליל')
# Span(start_index=415, end_index=422, text='בן דורי')
# Only in Ayala Dvir:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=186, end_index=198, text='601,016 דולר')
# Span(start_index=41, end_index=53, text='חברת התיירות')
# Span(start_index=54, end_index=63, text='אמין טורס')
# Span(start_index=36, end_index=53, text='נשיא חברת התיירות')
# Span(start_index=28, end_index=32, text='ארצה')
# Span(start_index=194, end_index=198, text='דולר')
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=127, end_index=138, text='טיולי הגליל')
# Span(start_index=436, end_index=440, text='_הוא')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# Span(start_index=36, end_index=63, text='נשיא חברת התיירות אמין טורס')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=697, end_index=702, text='ארה"ב')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=416, end_index=444, text='צבי קורן, מנכ"ל משרד התעשייה')
# Span(start_index=394, end_index=414, text='מכון התקנים האמריקאי')
# Span(start_index=152, end_index=163, text='ישראל-ארה"ב')
# Span(start_index=416, end_index=424, text='צבי קורן')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=147, end_index=151, text='מו"ף')
# Span(start_index=426, end_index=444, text='מנכ"ל משרד התעשייה')
# Span(start_index=113, end_index=185, text='מועצת המנהלים של הקרן הדו-לאומית למו"ף ישראל-ארה"ב שתתכנס השבוע בירושלים')
# Span(start_index=130, end_index=163, text='הקרן הדו-לאומית למו"ף ישראל-ארה"ב')
# Span(start_index=24, end_index=28, text='מחקר')
# Span(start_index=635, end_index=663, text='הקרן הדו-לאומית למחקר ופיתוח')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Only in Ayala Dvir:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=63, end_index=67, text='דולר')
# Span(start_index=307, end_index=312, text='האוצר')
# Span(start_index=652, end_index=663, text='מחקר ופיתוח')
# Span(start_index=130, end_index=145, text='הקרן הדו-לאומית')
# Span(start_index=606, end_index=633, text='ה_סכום הקרוב לכמיליארד דולר')
# Span(start_index=482, end_index=490, text='פרויקטים')
# Span(start_index=568, end_index=584, text='המכירות המצטברות')
# Span(start_index=766, end_index=808, text='מימון פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=472, end_index=480, text='עדיפויות')
# Span(start_index=851, end_index=855, text='דולר')
# Span(start_index=835, end_index=838, text='קרן')
# Span(start_index=50, end_index=67, text='שמונה מיליון דולר')
# Span(start_index=113, end_index=126, text='מועצת המנהלים')
# Span(start_index=8, end_index=22, text='פרויקטים חדשים')
# Span(start_index=576, end_index=584, text='המצטברות')
# Span(start_index=671, end_index=679, text='שנת 1977')
# Span(start_index=727, end_index=731, text='דולר')
# Span(start_index=595, end_index=604, text='עזרת הקרן')
# Span(start_index=717, end_index=731, text='30 מיליון דולר')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=335, end_index=341, text='תעשייה')
# Span(start_index=840, end_index=855, text='110 מיליון דולר')
# Span(start_index=601, end_index=604, text='קרן')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=829, end_index=838, text='סכום הקרן')
# Span(start_index=606, end_index=618, text='ה_סכום הקרוב')
# Span(start_index=586, end_index=593, text='פיתוחים')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=378, end_index=391, text='התעשייה, החוץ')
# 0.6775956284153005
# score for Yuval Sagi
# 60
# Disagreement
# Only in gold:
# Span(start_index=416, end_index=421, text='המקום')
# Span(start_index=199, end_index=213, text='העיצוב והתכנון')
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=479, end_index=487, text='586 דולר')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=338, end_index=342, text='השנה')
# Span(start_index=275, end_index=280, text='אפקוט')
# Span(start_index=240, end_index=256, text='אוניברסיטת דיסני')
# Span(start_index=139, end_index=144, text='המקום')
# Span(start_index=270, end_index=273, text='מסע')
# Span(start_index=295, end_index=308, text='ציור או רישום')
# Span(start_index=96, end_index=108, text='תכנון הסביבה')
# Only in Yuval Sagi:
# Span(start_index=338, end_index=339, text='ה')
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=110, end_index=115, text='סמינר')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=12, end_index=19, text='הצהריים')
# Span(start_index=356, end_index=360, text='ימים')
# Span(start_index=494, end_index=500, text='חומרים')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=64, end_index=94, text='מאחורי הקלעים של עיצוב המשטחים')
# 10
# Disagreement
# Only in gold:
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=457, end_index=464, text='המחלוקת')
# Span(start_index=324, end_index=331, text='ירושלים')
# Span(start_index=256, end_index=262, text='ה_תוהו')
# Span(start_index=415, end_index=422, text='בן דורי')
# Only in Yuval Sagi:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=41, end_index=53, text='חברת התיירות')
# Span(start_index=54, end_index=63, text='אמין טורס')
# Span(start_index=36, end_index=53, text='נשיא חברת התיירות')
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=127, end_index=138, text='טיולי הגליל')
# Span(start_index=436, end_index=440, text='_הוא')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=298, end_index=312, text='התעשייה והאוצר')
# Span(start_index=171, end_index=176, text='השבוע')
# Span(start_index=635, end_index=663, text='הקרן הדו-לאומית למחקר ופיתוח')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=811, end_index=821, text='מרוצת הזמן')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=733, end_index=738, text='ה_קרן')
# Span(start_index=158, end_index=163, text='ארה"ב')
# Span(start_index=207, end_index=259, text='אלקטרוניקה, מחשבים, תוכנה, טלקומוניקציה ומערכות בקרה')
# Span(start_index=37, end_index=67, text='היקף כולל של שמונה מיליון דולר')
# Span(start_index=373, end_index=391, text='משרד התעשייה, החוץ')
# Span(start_index=292, end_index=312, text='משרדי התעשייה והאוצר')
# Span(start_index=279, end_index=284, text='ה_קרן')
# Span(start_index=187, end_index=196, text='הפרויקטים')
# Span(start_index=113, end_index=185, text='מועצת המנהלים של הקרן הדו-לאומית למו"ף ישראל-ארה"ב שתתכנס השבוע בירושלים')
# Span(start_index=535, end_index=549, text='חברות ישראליות')
# Span(start_index=152, end_index=163, text='ישראל-ארה"ב')
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=207, end_index=217, text='אלקטרוניקה')
# Span(start_index=752, end_index=758, text='ההשקעה')
# Only in Yuval Sagi:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=766, end_index=808, text='מימון פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=671, end_index=679, text='שנת 1977')
# Span(start_index=69, end_index=104, text='המשותפים לחברות ישראליות ואמריקאיות')
# Span(start_index=50, end_index=67, text='שמונה מיליון דולר')
# Span(start_index=307, end_index=312, text='האוצר')
# Span(start_index=576, end_index=584, text='המצטברות')
# Span(start_index=586, end_index=593, text='פיתוחים')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=606, end_index=618, text='ה_סכום הקרוב')
# Span(start_index=829, end_index=838, text='סכום הקרן')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=378, end_index=391, text='התעשייה, החוץ')
# Span(start_index=840, end_index=855, text='110 מיליון דולר')
# 0.7181208053691275
# score for hadar livyatan
# 60
# Disagreement
# Only in gold:
# Span(start_index=350, end_index=360, text='שלושה ימים')
# Span(start_index=479, end_index=487, text='586 דולר')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=8, end_index=19, text='אחר-הצהריים')
# Only in hadar livyatan:
# Span(start_index=176, end_index=189, text='פעילות היומית')
# Span(start_index=576, end_index=586, text='אתרי הנופש')
# Span(start_index=64, end_index=77, text='מאחורי הקלעים')
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=516, end_index=528, text='תקופה ממושכת')
# Span(start_index=12, end_index=19, text='הצהריים')
# Span(start_index=503, end_index=528, text='הורים הבאים לתקופה ממושכת')
# Span(start_index=129, end_index=135, text='צמחייה')
# Span(start_index=503, end_index=508, text='הורים')
# Span(start_index=494, end_index=500, text='חומרים')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=550, end_index=561, text='שעות ארוכות')
# 10
# Disagreement
# Only in gold:
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=415, end_index=422, text='בן דורי')
# Only in hadar livyatan:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=41, end_index=53, text='חברת התיירות')
# Span(start_index=54, end_index=63, text='אמין טורס')
# Span(start_index=36, end_index=53, text='נשיא חברת התיירות')
# Span(start_index=28, end_index=32, text='ארצה')
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=127, end_index=138, text='טיולי הגליל')
# Span(start_index=436, end_index=440, text='_הוא')
# Span(start_index=105, end_index=126, text='חברת התיירות הישראלית')
# Span(start_index=313, end_index=322, text='משרד החוץ')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Only in hadar livyatan:
# Span(start_index=795, end_index=800, text='המחקר')
# Span(start_index=766, end_index=808, text='מימון פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=472, end_index=480, text='עדיפויות')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=671, end_index=679, text='שנת 1977')
# Span(start_index=307, end_index=312, text='האוצר')
# Span(start_index=8, end_index=22, text='פרויקטים חדשים')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=829, end_index=838, text='סכום הקרן')
# Span(start_index=606, end_index=618, text='ה_סכום הקרוב')
# Span(start_index=652, end_index=663, text='מחקר ופיתוח')
# Span(start_index=576, end_index=584, text='המצטברות')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=742, end_index=748, text='הריבית')
# Span(start_index=595, end_index=604, text='עזרת הקרן')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=378, end_index=391, text='התעשייה, החוץ')
# 0.7657142857142857
# score for Rom Golan
# 60
# Disagreement
# Only in gold:
# Span(start_index=64, end_index=108, text='מאחורי הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=588, end_index=595, text='ה_סביבה')
# Span(start_index=295, end_index=299, text='ציור')
# Span(start_index=199, end_index=205, text='העיצוב')
# Span(start_index=416, end_index=421, text='המקום')
# Span(start_index=71, end_index=108, text='הקלעים של עיצוב המשטחים ותכנון הסביבה')
# Span(start_index=81, end_index=94, text='עיצוב המשטחים')
# Span(start_index=152, end_index=156, text='ה_חי')
# Span(start_index=303, end_index=308, text='רישום')
# Span(start_index=295, end_index=308, text='ציור או רישום')
# Span(start_index=174, end_index=213, text='ה_פעילות היומית של עובדי העיצוב והתכנון')
# Span(start_index=598, end_index=607, text='בית המלון')
# Span(start_index=207, end_index=213, text='התכנון')
# Span(start_index=139, end_index=144, text='המקום')
# Span(start_index=440, end_index=443, text='_הם')
# Span(start_index=461, end_index=472, text='סמינר כה_זה')
# Span(start_index=199, end_index=213, text='העיצוב והתכנון')
# Span(start_index=452, end_index=501, text='השתתפות בסמינר כה_זה תעלה כ586 דולר (כולל חומרים)')
# Span(start_index=275, end_index=280, text='אפקוט')
# Span(start_index=445, end_index=450, text='ה_שטח')
# Span(start_index=468, end_index=472, text='ה_זה')
# Span(start_index=470, end_index=472, text='זה')
# Span(start_index=270, end_index=273, text='מסע')
# Span(start_index=96, end_index=108, text='תכנון הסביבה')
# Only in Rom Golan:
# Span(start_index=64, end_index=77, text='מאחורי הקלעים')
# Span(start_index=270, end_index=280, text='מסע לאפקוט')
# Span(start_index=541, end_index=548, text='הצעירים')
# Span(start_index=388, end_index=396, text='המשתתפים')
# Span(start_index=503, end_index=528, text='הורים הבאים לתקופה ממושכת')
# Span(start_index=151, end_index=156, text='בה_חי')
# Span(start_index=193, end_index=205, text='עובדי העיצוב')
# Span(start_index=225, end_index=256, text='חדרי הלימוד של אוניברסיטת דיסני')
# Span(start_index=129, end_index=144, text='צמחייה של המקום')
# 10
# Disagreement
# Only in gold:
# Span(start_index=410, end_index=422, text='עזרא בן דורי')
# Span(start_index=206, end_index=213, text='שבראווי')
# Span(start_index=397, end_index=408, text='טיולי הגליל')
# Span(start_index=457, end_index=464, text='המחלוקת')
# Span(start_index=366, end_index=370, text='_היא')
# Span(start_index=246, end_index=250, text='החוב')
# Span(start_index=41, end_index=63, text='חברת התיירות אמין טורס')
# Span(start_index=288, end_index=292, text='קהיר')
# Span(start_index=221, end_index=250, text='כל מאמץ_של__הוא לגבות את החוב')
# Span(start_index=65, end_index=77, text='אמין שבראווי')
# Span(start_index=324, end_index=331, text='ירושלים')
# Span(start_index=386, end_index=408, text='מנכ"ל חברת טיולי הגליל')
# Span(start_index=392, end_index=408, text='חברת טיולי הגליל')
# Span(start_index=256, end_index=262, text='ה_תוהו')
# Span(start_index=415, end_index=422, text='בן דורי')
# Only in Rom Golan:
# Span(start_index=181, end_index=185, text='_היא')
# Span(start_index=186, end_index=198, text='601,016 דולר')
# Span(start_index=162, end_index=173, text='טיולי הגליל')
# Span(start_index=313, end_index=331, text='משרד החוץ בירושלים')
# 64
# Disagreement
# Only in gold:
# Span(start_index=298, end_index=312, text='התעשייה והאוצר')
# Span(start_index=343, end_index=348, text='המסחר')
# Span(start_index=652, end_index=656, text='מחקר')
# Span(start_index=334, end_index=341, text='התעשייה')
# Span(start_index=635, end_index=663, text='הקרן הדו-לאומית למחקר ופיתוח')
# Span(start_index=285, end_index=312, text='מנכ"לי משרדי התעשייה והאוצר')
# Span(start_index=197, end_index=199, text='הם')
# Span(start_index=373, end_index=414, text='משרד התעשייה, החוץ, ומכון התקנים האמריקאי')
# Span(start_index=802, end_index=808, text='הפיתוח')
# Span(start_index=704, end_index=709, text='ישראל')
# Span(start_index=823, end_index=855, text='הועלה סכום הקרן ל110 מיליון דולר')
# Span(start_index=426, end_index=444, text='מנכ"ל משרד התעשייה')
# Span(start_index=158, end_index=163, text='ארה"ב')
# Span(start_index=658, end_index=663, text='פיתוח')
# Span(start_index=772, end_index=808, text='פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=373, end_index=391, text='משרד התעשייה, החוץ')
# Span(start_index=334, end_index=348, text='התעשייה והמסחר')
# Span(start_index=387, end_index=391, text='החוץ')
# Span(start_index=462, end_index=466, text='_הוא')
# Span(start_index=394, end_index=414, text='מכון התקנים האמריקאי')
# Span(start_index=697, end_index=702, text='ארה"ב')
# Span(start_index=795, end_index=808, text='המחקר והפיתוח')
# Span(start_index=298, end_index=305, text='התעשייה')
# Span(start_index=152, end_index=163, text='ישראל-ארה"ב')
# Span(start_index=152, end_index=157, text='ישראל')
# Span(start_index=378, end_index=385, text='התעשייה')
# Span(start_index=147, end_index=151, text='מו"ף')
# Span(start_index=752, end_index=758, text='ההשקעה')
# Span(start_index=353, end_index=358, text='ארה"ב')
# Only in Rom Golan:
# Span(start_index=766, end_index=808, text='מימון פרויקטים משותפים בתחום המחקר והפיתוח')
# Span(start_index=635, end_index=679, text='הקרן הדו-לאומית למחקר ופיתוח הוקמה בשנת 1977')
# Span(start_index=682, end_index=688, text='שנה זו')
# Span(start_index=50, end_index=67, text='שמונה מיליון דולר')
# Span(start_index=742, end_index=758, text='הריבית על ההשקעה')
# Span(start_index=146, end_index=163, text='למו"ף ישראל-ארה"ב')
# Span(start_index=717, end_index=731, text='30 מיליון דולר')
# Span(start_index=492, end_index=495, text='_הם')
# Span(start_index=621, end_index=633, text='מיליארד דולר')
# Span(start_index=509, end_index=530, text='חברות אמריקאיות חדשות')
# Span(start_index=840, end_index=855, text='110 מיליון דולר')
# 0.5310344827586206
