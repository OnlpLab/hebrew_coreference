# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from mention_agreemnet_utils import process_annotations, read_annotation_data

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../mention_annotation_data"

# %%
set(list(range(96,101)))
# Out:
# {96, 97, 98, 99, 100}

# %%
file_by_annotator = read_annotation_data(conllu_annotated_files_path, specific_files={96} , exclude={'Shaked'})

# %%
process_annotations(file_by_annotator)
# Out:
# 0.7439446366782007

# %%
desired_keys = ['Ido', 'Consolidation']

Elisheva_Ido = {key: file_by_annotator[key] for key in desired_keys if key in file_by_annotator}

process_annotations(Elisheva_Ido)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[103], line 5
#       1 desired_keys = ['Ido', 'Consolidation']
#       3 Elisheva_Ido = {key: file_by_annotator[key] for key in desired_keys if key in file_by_annotator}
# ----> 5 process_annotations(Elisheva_Ido)
#
# File ~/studies/tne_ui/hebrew_coref/agreement/mention_agreement/mention_agreemnet_utils.py:40, in process_annotations(annotations)
#      37                 agreement_spans += len(set(spans1) & set(spans2))
#      39                 # calculate agreement
# ---> 40 agreement = agreement_spans / total_spans  # it is the ratio of the spans that both annotators agreed upon to the total number of spans
#      41 return agreement
#
# ZeroDivisionError: division by zero

# %%
desired_keys = ['Consolidation', 'Elisheva']

Elisheva_Ido = {key: file_by_annotator[key] for key in desired_keys if key in file_by_annotator}

process_annotations(Elisheva_Ido)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[104], line 5
#       1 desired_keys = ['Consolidation', 'Elisheva']
#       3 Elisheva_Ido = {key: file_by_annotator[key] for key in desired_keys if key in file_by_annotator}
# ----> 5 process_annotations(Elisheva_Ido)
#
# File ~/studies/tne_ui/hebrew_coref/agreement/mention_agreement/mention_agreemnet_utils.py:40, in process_annotations(annotations)
#      37                 agreement_spans += len(set(spans1) & set(spans2))
#      39                 # calculate agreement
# ---> 40 agreement = agreement_spans / total_spans  # it is the ratio of the spans that both annotators agreed upon to the total number of spans
#      41 return agreement
#
# ZeroDivisionError: division by zero

# %%
desired_keys = ['Consolidation', 'Arbel']

Arbel_Ido = {key: file_by_annotator[key] for key in desired_keys if key in file_by_annotator}

process_annotations(Arbel_Ido)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[105], line 5
#       1 desired_keys = ['Consolidation', 'Arbel']
#       3 Arbel_Ido = {key: file_by_annotator[key] for key in desired_keys if key in file_by_annotator}
# ----> 5 process_annotations(Arbel_Ido)
#
# File ~/studies/tne_ui/hebrew_coref/agreement/mention_agreement/mention_agreemnet_utils.py:40, in process_annotations(annotations)
#      37                 agreement_spans += len(set(spans1) & set(spans2))
#      39                 # calculate agreement
# ---> 40 agreement = agreement_spans / total_spans  # it is the ratio of the spans that both annotators agreed upon to the total number of spans
#      41 return agreement
#
# ZeroDivisionError: division by zero
