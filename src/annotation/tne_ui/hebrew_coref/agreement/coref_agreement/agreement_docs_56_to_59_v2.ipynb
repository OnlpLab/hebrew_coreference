# %%
% load_ext autoreload
% autoreload 2

# %%
import os
from collections import defaultdict
import pandas as pd
from agreement_utils import extract_name, two_annotators_agreement, n_annotators_agreement
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../conllu_out_annotation/documents_56_to_59_v2"

# %%
file_by_annotator = defaultdict(list)
conllu_annotated_files = os.listdir(conllu_annotated_files_path)
for f in conllu_annotated_files:
    file_by_annotator[extract_name(f)].append(f)
keep_singletons = False
calc_with_mentions = False

Yechiel_vs_Hadas = two_annotators_agreement("Yechiel", "Hadas", keep_singletons, calc_with_mentions, file_by_annotator,
                                            conllu_annotated_files_path)

Hadas_vs_Hinoy = two_annotators_agreement("Hadas", "Hinoy", keep_singletons, calc_with_mentions, file_by_annotator,
                                          conllu_annotated_files_path)
Hinoy_vs_Yechiel = two_annotators_agreement("Hinoy", "Yechiel", keep_singletons, calc_with_mentions, file_by_annotator,
                                            conllu_annotated_files_path)

third_round_agreement = [
    ("Yechiel_vs_Hadas No Singletons", Yechiel_vs_Hadas),
    ("Hadas_vs_Hinoy No Singletons", Hadas_vs_Hinoy),
    ("Hinoy_vs_Yechiel No Singletons", Hinoy_vs_Yechiel)]
# Out:
# 45 and 49 singletons are removed from the key and system files, respectively
# mentions   Recall: 88.89  Precision: 100.00  F1: 94.12
# muc        Recall: 89.29  Precision: 100.00  F1: 94.34
# bcub       Recall: 84.58  Precision: 100.00  F1: 91.65
# ceafe      Recall: 84.33  Precision: 96.37  F1: 89.95
# lea        Recall: 83.33  Precision: 100.00  F1: 90.91
# CoNLL score: 91.71
# 53 and 65 singletons are removed from the key and system files, respectively
# mentions   Recall: 75.00  Precision: 100.00  F1: 85.71
# muc        Recall: 71.88  Precision: 95.83  F1: 82.14
# bcub       Recall: 67.99  Precision: 95.83  F1: 79.54
# ceafe      Recall: 69.29  Precision: 92.38  F1: 79.18
# lea        Recall: 65.62  Precision: 94.44  F1: 77.44
# CoNLL score: 79.58
# 57 and 62 singletons are removed from the key and system files, respectively
# mentions   Recall: 90.54  Precision: 97.10  F1: 93.71
# muc        Recall: 86.21  Precision: 92.59  F1: 89.29
# bcub       Recall: 82.60  Precision: 88.44  F1: 85.42
# ceafe      Recall: 79.48  Precision: 84.78  F1: 82.05
# lea        Recall: 81.08  Precision: 86.80  F1: 83.84
# CoNLL score: 85.15
# 49 and 44 singletons are removed from the key and system files, respectively
# mentions   Recall: 96.88  Precision: 83.78  F1: 89.86
# muc        Recall: 88.00  Precision: 81.48  F1: 84.62
# bcub       Recall: 83.28  Precision: 76.37  F1: 79.68
# ceafe      Recall: 89.57  Precision: 62.70  F1: 73.76
# lea        Recall: 79.17  Precision: 72.97  F1: 75.94
# CoNLL score: 78.50
# 62 and 59 singletons are removed from the key and system files, respectively
# mentions   Recall: 97.10  Precision: 93.06  F1: 95.04
# muc        Recall: 92.59  Precision: 84.75  F1: 88.50
# bcub       Recall: 88.03  Precision: 79.55  F1: 83.57
# ceafe      Recall: 79.15  Precision: 91.33  F1: 84.81
# lea        Recall: 86.96  Precision: 77.62  F1: 82.03
# CoNLL score: 84.72
# 65 and 55 singletons are removed from the key and system files, respectively
# mentions   Recall: 97.22  Precision: 76.09  F1: 85.37
# muc        Recall: 87.50  Precision: 67.74  F1: 76.36
# bcub       Recall: 87.04  Precision: 65.94  F1: 75.04
# ceafe      Recall: 87.26  Precision: 69.81  F1: 77.57
# lea        Recall: 83.33  Precision: 61.74  F1: 70.93
# CoNLL score: 74.97
# 44 and 45 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.89  Precision: 94.44  F1: 93.15
# muc        Recall: 88.89  Precision: 85.71  F1: 87.27
# bcub       Recall: 86.28  Precision: 79.17  F1: 82.57
# ceafe      Recall: 73.06  Precision: 91.32  F1: 81.17
# lea        Recall: 83.78  Precision: 75.00  F1: 79.15
# CoNLL score: 82.54
# 59 and 57 singletons are removed from the key and system files, respectively
# mentions   Recall: 97.22  Precision: 94.59  F1: 95.89
# muc        Recall: 91.53  Precision: 93.10  F1: 92.31
# bcub       Recall: 84.99  Precision: 88.08  F1: 86.51
# ceafe      Recall: 94.52  Precision: 76.79  F1: 84.74
# lea        Recall: 83.18  Precision: 87.26  F1: 85.17
# CoNLL score: 87.18
# 55 and 53 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.30  Precision: 87.50  F1: 89.36
# muc        Recall: 87.10  Precision: 84.38  F1: 85.71
# bcub       Recall: 85.51  Precision: 81.94  F1: 83.69
# ceafe      Recall: 82.44  Precision: 77.29  F1: 79.78
# lea        Recall: 82.61  Precision: 79.17  F1: 80.85
# CoNLL score: 82.51

# %%
Yechiel_vs_Hadas
# Out:
# {'muc': {'recall': 0.8245587027914615,
#   'precision': 0.9614197530864198,
#   'f1': 0.8858939802336029},
#  'bcub': {'recall': 0.7839083401583401,
#   'precision': 0.9475711218464843,
#   'f1': 0.8553724793688539},
#  'ceafe': {'recall': 0.7769763460939932,
#   'precision': 0.9117780445511539,
#   'f1': 0.837254949769633},
#  'lea': {'recall': 0.7667980480480482,
#   'precision': 0.9374664519592056,
#   'f1': 0.840634888931684}}

# %%
Hadas_vs_Hinoy
# Out:
# {'muc': {'recall': 0.893641975308642,
#   'precision': 0.7798972655907228,
#   'f1': 0.8315819873341996},
#  'bcub': {'recall': 0.8611448878885474,
#   'precision': 0.7395310330092938,
#   'f1': 0.7942762574564934},
#  'ceafe': {'recall': 0.8532815597101311,
#   'precision': 0.7461292838215915,
#   'f1': 0.7871206420926309},
#  'lea': {'recall': 0.8315217391304347,
#   'precision': 0.7077852006595968,
#   'f1': 0.7629939134756211}}

# %%
Hinoy_vs_Yechiel
# Out:
# {'muc': {'recall': 0.8917036227041694,
#   'precision': 0.8773091133004925,
#   'f1': 0.8843156843156842},
#  'bcub': {'recall': 0.8559211879864055,
#   'precision': 0.8306488306488307,
#   'f1': 0.8425563839149613},
#  'ceafe': {'recall': 0.8333783697096391,
#   'precision': 0.818009926591583,
#   'f1': 0.8189794381695293},
#  'lea': {'recall': 0.8319049726054556,
#   'precision': 0.8047511797511797,
#   'f1': 0.8172334110589444}}

# %%
for name, score in third_round_agreement:
    print(name + " Conll score by muc, bcub, ceafe, lea  (without Mentions)")
    df = pd.DataFrame(score)
    df['mean'] = df.mean(axis=1)
    print(df['mean']['f1'])
# Out:
# Yechiel_vs_Hadas No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# 0.8547890745759434
# Hadas_vs_Hinoy No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# 0.7939932000897363
# Hinoy_vs_Yechiel No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# 0.8407712293647799

# %%
should_keep_singleton = False
include_mentions = False
scores = n_annotators_agreement(["Hinoy", "Yechiel", "Hadas"], should_keep_singleton, include_mentions,
                                file_by_annotator, conllu_annotated_files_path)
# Out:
# keep_singletons: False
# include_mentions: False
# Check agreement for 3 files
# name1:  Hinoy
# name2:  Yechiel
# Number of file coules: 3
# name1:  Hinoy
# name2:  Hadas
# Number of file coules: 3
# name1:  Yechiel
# name2:  Hadas
# Number of file coules: 3
# 44 and 45 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.89  Precision: 94.44  F1: 93.15
# muc        Recall: 88.89  Precision: 85.71  F1: 87.27
# bcub       Recall: 86.28  Precision: 79.17  F1: 82.57
# ceafe      Recall: 73.06  Precision: 91.32  F1: 81.17
# lea        Recall: 83.78  Precision: 75.00  F1: 79.15
# CoNLL score: 82.54
# 59 and 57 singletons are removed from the key and system files, respectively
# mentions   Recall: 97.22  Precision: 94.59  F1: 95.89
# muc        Recall: 91.53  Precision: 93.10  F1: 92.31
# bcub       Recall: 84.99  Precision: 88.08  F1: 86.51
# ceafe      Recall: 94.52  Precision: 76.79  F1: 84.74
# lea        Recall: 83.18  Precision: 87.26  F1: 85.17
# CoNLL score: 87.18
# 55 and 53 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.30  Precision: 87.50  F1: 89.36
# muc        Recall: 87.10  Precision: 84.38  F1: 85.71
# bcub       Recall: 85.51  Precision: 81.94  F1: 83.69
# ceafe      Recall: 82.44  Precision: 77.29  F1: 79.78
# lea        Recall: 82.61  Precision: 79.17  F1: 80.85
# CoNLL score: 82.51
# 44 and 49 singletons are removed from the key and system files, respectively
# mentions   Recall: 83.78  Precision: 96.88  F1: 89.86
# muc        Recall: 81.48  Precision: 88.00  F1: 84.62
# bcub       Recall: 76.37  Precision: 83.28  F1: 79.68
# ceafe      Recall: 62.70  Precision: 89.57  F1: 73.76
# lea        Recall: 72.97  Precision: 79.17  F1: 75.94
# CoNLL score: 78.50
# 59 and 62 singletons are removed from the key and system files, respectively
# mentions   Recall: 93.06  Precision: 97.10  F1: 95.04
# muc        Recall: 84.75  Precision: 92.59  F1: 88.50
# bcub       Recall: 79.55  Precision: 88.03  F1: 83.57
# ceafe      Recall: 91.33  Precision: 79.15  F1: 84.81
# lea        Recall: 77.62  Precision: 86.96  F1: 82.03
# CoNLL score: 84.72
# 55 and 65 singletons are removed from the key and system files, respectively
# mentions   Recall: 76.09  Precision: 97.22  F1: 85.37
# muc        Recall: 67.74  Precision: 87.50  F1: 76.36
# bcub       Recall: 65.94  Precision: 87.04  F1: 75.04
# ceafe      Recall: 69.81  Precision: 87.26  F1: 77.57
# lea        Recall: 61.74  Precision: 83.33  F1: 70.93
# CoNLL score: 74.97
# 45 and 49 singletons are removed from the key and system files, respectively
# mentions   Recall: 88.89  Precision: 100.00  F1: 94.12
# muc        Recall: 89.29  Precision: 100.00  F1: 94.34
# bcub       Recall: 84.58  Precision: 100.00  F1: 91.65
# ceafe      Recall: 84.33  Precision: 96.37  F1: 89.95
# lea        Recall: 83.33  Precision: 100.00  F1: 90.91
# CoNLL score: 91.71
# 53 and 65 singletons are removed from the key and system files, respectively
# mentions   Recall: 75.00  Precision: 100.00  F1: 85.71
# muc        Recall: 71.88  Precision: 95.83  F1: 82.14
# bcub       Recall: 67.99  Precision: 95.83  F1: 79.54
# ceafe      Recall: 69.29  Precision: 92.38  F1: 79.18
# lea        Recall: 65.62  Precision: 94.44  F1: 77.44
# CoNLL score: 79.58
# 57 and 62 singletons are removed from the key and system files, respectively
# mentions   Recall: 90.54  Precision: 97.10  F1: 93.71
# muc        Recall: 86.21  Precision: 92.59  F1: 89.29
# bcub       Recall: 82.60  Precision: 88.44  F1: 85.42
# ceafe      Recall: 79.48  Precision: 84.78  F1: 82.05
# lea        Recall: 81.08  Precision: 86.80  F1: 83.84
# CoNLL score: 85.15

# %%
print('Total score of "Hinoy", "Yechiel", "Hadas with mentions: ')
data = {'values': [pd.DataFrame(score).loc['f1'].mean() for score in scores]}
df = pd.DataFrame(data)

print(df['values'].mean())
# Out:
# Total score of "Hinoy", "Yechiel", "Hadas with mentions:
# 0.8298511680101531

# %%
should_keep_singleton = False
include_mentions = False
scores = n_annotators_agreement(["Hinoy", "Yechiel", "Hadas"], should_keep_singleton, include_mentions,
                                file_by_annotator, conllu_annotated_files_path)
# Out:
# keep_singletons: False
# include_mentions: False
# Check agreement for 3 files
# name1:  Hinoy
# name2:  Yechiel
# Number of file coules: 3
# name1:  Hinoy
# name2:  Hadas
# Number of file coules: 3
# name1:  Yechiel
# name2:  Hadas
# Number of file coules: 3
# 44 and 45 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.89  Precision: 94.44  F1: 93.15
# muc        Recall: 88.89  Precision: 85.71  F1: 87.27
# bcub       Recall: 86.28  Precision: 79.17  F1: 82.57
# ceafe      Recall: 73.06  Precision: 91.32  F1: 81.17
# lea        Recall: 83.78  Precision: 75.00  F1: 79.15
# CoNLL score: 82.54
# 59 and 57 singletons are removed from the key and system files, respectively
# mentions   Recall: 97.22  Precision: 94.59  F1: 95.89
# muc        Recall: 91.53  Precision: 93.10  F1: 92.31
# bcub       Recall: 84.99  Precision: 88.08  F1: 86.51
# ceafe      Recall: 94.52  Precision: 76.79  F1: 84.74
# lea        Recall: 83.18  Precision: 87.26  F1: 85.17
# CoNLL score: 87.18
# 55 and 53 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.30  Precision: 87.50  F1: 89.36
# muc        Recall: 87.10  Precision: 84.38  F1: 85.71
# bcub       Recall: 85.51  Precision: 81.94  F1: 83.69
# ceafe      Recall: 82.44  Precision: 77.29  F1: 79.78
# lea        Recall: 82.61  Precision: 79.17  F1: 80.85
# CoNLL score: 82.51
# 44 and 49 singletons are removed from the key and system files, respectively
# mentions   Recall: 83.78  Precision: 96.88  F1: 89.86
# muc        Recall: 81.48  Precision: 88.00  F1: 84.62
# bcub       Recall: 76.37  Precision: 83.28  F1: 79.68
# ceafe      Recall: 62.70  Precision: 89.57  F1: 73.76
# lea        Recall: 72.97  Precision: 79.17  F1: 75.94
# CoNLL score: 78.50
# 59 and 62 singletons are removed from the key and system files, respectively
# mentions   Recall: 93.06  Precision: 97.10  F1: 95.04
# muc        Recall: 84.75  Precision: 92.59  F1: 88.50
# bcub       Recall: 79.55  Precision: 88.03  F1: 83.57
# ceafe      Recall: 91.33  Precision: 79.15  F1: 84.81
# lea        Recall: 77.62  Precision: 86.96  F1: 82.03
# CoNLL score: 84.72
# 55 and 65 singletons are removed from the key and system files, respectively
# mentions   Recall: 76.09  Precision: 97.22  F1: 85.37
# muc        Recall: 67.74  Precision: 87.50  F1: 76.36
# bcub       Recall: 65.94  Precision: 87.04  F1: 75.04
# ceafe      Recall: 69.81  Precision: 87.26  F1: 77.57
# lea        Recall: 61.74  Precision: 83.33  F1: 70.93
# CoNLL score: 74.97
# 45 and 49 singletons are removed from the key and system files, respectively
# mentions   Recall: 88.89  Precision: 100.00  F1: 94.12
# muc        Recall: 89.29  Precision: 100.00  F1: 94.34
# bcub       Recall: 84.58  Precision: 100.00  F1: 91.65
# ceafe      Recall: 84.33  Precision: 96.37  F1: 89.95
# lea        Recall: 83.33  Precision: 100.00  F1: 90.91
# CoNLL score: 91.71
# 53 and 65 singletons are removed from the key and system files, respectively
# mentions   Recall: 75.00  Precision: 100.00  F1: 85.71
# muc        Recall: 71.88  Precision: 95.83  F1: 82.14
# bcub       Recall: 67.99  Precision: 95.83  F1: 79.54
# ceafe      Recall: 69.29  Precision: 92.38  F1: 79.18
# lea        Recall: 65.62  Precision: 94.44  F1: 77.44
# CoNLL score: 79.58
# 57 and 62 singletons are removed from the key and system files, respectively
# mentions   Recall: 90.54  Precision: 97.10  F1: 93.71
# muc        Recall: 86.21  Precision: 92.59  F1: 89.29
# bcub       Recall: 82.60  Precision: 88.44  F1: 85.42
# ceafe      Recall: 79.48  Precision: 84.78  F1: 82.05
# lea        Recall: 81.08  Precision: 86.80  F1: 83.84
# CoNLL score: 85.15

# %%
print('Total score of "Hinoy", "Yechiel", "Hadas" no mentions: ')
data_no_mentions = {'values': [pd.DataFrame(score).loc['f1'].mean() for score in scores]}
df_no_mentions = pd.DataFrame(data_no_mentions)
print(df_no_mentions['values'].mean())
# Out:
# Total score of "Hinoy", "Yechiel", "Hadas" no mentions:
# 0.8298511680101531

# %%
scores
# Out:
# [{'muc': {'recall': 0.8917036227041694,
#    'precision': 0.8773091133004925,
#    'f1': 0.8843156843156842},
#   'bcub': {'recall': 0.8559211879864055,
#    'precision': 0.8306488306488307,
#    'f1': 0.8425563839149613},
#   'ceafe': {'recall': 0.8333783697096391,
#    'precision': 0.818009926591583,
#    'f1': 0.8189794381695293},
#   'lea': {'recall': 0.8319049726054556,
#    'precision': 0.8047511797511797,
#    'f1': 0.8172334110589444}},
#  {'muc': {'recall': 0.7798972655907228,
#    'precision': 0.893641975308642,
#    'f1': 0.8315819873341996},
#   'bcub': {'recall': 0.7395310330092938,
#    'precision': 0.8611448878885474,
#    'f1': 0.7942762574564934},
#   'ceafe': {'recall': 0.7461292838215915,
#    'precision': 0.8532815597101311,
#    'f1': 0.7871206420926309},
#   'lea': {'recall': 0.7077852006595968,
#    'precision': 0.8315217391304347,
#    'f1': 0.7629939134756211}},
#  {'muc': {'recall': 0.8245587027914615,
#    'precision': 0.9614197530864198,
#    'f1': 0.8858939802336029},
#   'bcub': {'recall': 0.7839083401583401,
#    'precision': 0.9475711218464843,
#    'f1': 0.8553724793688539},
#   'ceafe': {'recall': 0.7769763460939932,
#    'precision': 0.9117780445511539,
#    'f1': 0.837254949769633},
#   'lea': {'recall': 0.7667980480480482,
#    'precision': 0.9374664519592056,
#    'f1': 0.840634888931684}}]

# %%
df_no_mentions
# Out:
#      values
# 0  0.840771
# 1  0.793993
# 2  0.854789

# %%
print(df_no_mentions.mean())
# Out:
# values    0.829851
# dtype: float64
