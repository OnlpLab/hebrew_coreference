# %%
% load_ext autoreload
% autoreload 2

# %%
import os
from collections import defaultdict
import pandas as pd
from agreement_utils import extract_name, two_annotators_agreement, n_annotators_agreement
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../conllu_out_annotation/documents_16_17_19_20_21"

# %%
file_by_annotator = defaultdict(list)
conllu_annotated_files = os.listdir(conllu_annotated_files_path)
for f in conllu_annotated_files:
    file_by_annotator[extract_name(f)].append(f)
keep_singletons = False
calc_with_mentions = False

Yechiel_vs_Hadas = two_annotators_agreement("Yechiel", "Hadas", keep_singletons, calc_with_mentions, file_by_annotator,
                                            conllu_annotated_files_path)

Hadas_vs_Hinoy = two_annotators_agreement("Hadas", "Hinoy", keep_singletons, calc_with_mentions, file_by_annotator,
                                          conllu_annotated_files_path)
Hinoy_vs_Yechiel = two_annotators_agreement("Hinoy", "Yechiel", keep_singletons, calc_with_mentions, file_by_annotator,
                                            conllu_annotated_files_path)

third_round_agreement = [
    ("Yechiel_vs_Hadas No Singletons", Yechiel_vs_Hadas),
    ("Hadas_vs_Hinoy No Singletons", Hadas_vs_Hinoy),
    ("Hinoy_vs_Yechiel No Singletons", Hinoy_vs_Yechiel)]
# Out:
# 22 and 24 singletons are removed from the key and system files, respectively
# mentions   Recall: 82.61  Precision: 90.48  F1: 86.36
# muc        Recall: 80.00  Precision: 92.31  F1: 85.71
# bcub       Recall: 75.87  Precision: 90.48  F1: 82.53
# ceafe      Recall: 84.33  Precision: 84.33  F1: 84.33
# lea        Recall: 73.91  Precision: 90.48  F1: 81.36
# CoNLL score: 83.48
# 31 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 81.25  F1: 89.66
# muc        Recall: 100.00  Precision: 81.82  F1: 90.00
# bcub       Recall: 100.00  Precision: 77.08  F1: 87.06
# ceafe      Recall: 95.00  Precision: 76.00  F1: 84.44
# lea        Recall: 100.00  Precision: 75.00  F1: 85.71
# CoNLL score: 86.80
# 20 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.71  Precision: 100.00  F1: 92.31
# muc        Recall: 80.00  Precision: 100.00  F1: 88.89
# bcub       Recall: 75.00  Precision: 100.00  F1: 85.71
# ceafe      Recall: 92.86  Precision: 92.86  F1: 92.86
# lea        Recall: 71.43  Precision: 100.00  F1: 83.33
# CoNLL score: 87.70
# 45 and 52 singletons are removed from the key and system files, respectively
# mentions   Recall: 43.90  Precision: 56.25  F1: 49.32
# muc        Recall: 4.00  Precision: 5.26  F1: 4.55
# bcub       Recall: 19.92  Precision: 25.26  F1: 22.27
# ceafe      Recall: 28.45  Precision: 35.02  F1: 31.40
# lea        Recall: 4.88  Precision: 6.25  F1: 5.48
# CoNLL score: 15.92
# 21 and 17 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.67  Precision: 78.57  F1: 84.62
# muc        Recall: 94.44  Precision: 80.95  F1: 87.18
# bcub       Recall: 91.67  Precision: 73.02  F1: 81.29
# ceafe      Recall: 79.02  Precision: 67.73  F1: 72.94
# lea        Recall: 91.67  Precision: 71.43  F1: 80.29
# CoNLL score: 80.42
# 24 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 87.50  F1: 93.33
# muc        Recall: 92.31  Precision: 80.00  F1: 85.71
# bcub       Recall: 95.24  Precision: 82.64  F1: 88.49
# ceafe      Recall: 93.75  Precision: 83.33  F1: 88.24
# lea        Recall: 90.48  Precision: 79.17  F1: 84.44
# CoNLL score: 86.72
# 21 and 20 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 85.71  F1: 92.31
# muc        Recall: 100.00  Precision: 80.00  F1: 88.89
# bcub       Recall: 100.00  Precision: 75.00  F1: 85.71
# ceafe      Recall: 92.86  Precision: 92.86  F1: 92.86
# lea        Recall: 100.00  Precision: 71.43  F1: 83.33
# CoNLL score: 87.70
# 28 and 26 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 88.89  F1: 94.12
# muc        Recall: 100.00  Precision: 91.67  F1: 95.65
# bcub       Recall: 100.00  Precision: 88.89  F1: 94.12
# ceafe      Recall: 100.00  Precision: 83.33  F1: 90.91
# lea        Recall: 100.00  Precision: 88.89  F1: 94.12
# CoNLL score: 93.70
# 52 and 43 singletons are removed from the key and system files, respectively
# mentions   Recall: 56.25  Precision: 41.86  F1: 48.00
# muc        Recall: 5.26  Precision: 3.70  F1: 4.35
# bcub       Recall: 25.26  Precision: 18.68  F1: 21.48
# ceafe      Recall: 35.53  Precision: 28.87  F1: 31.86
# lea        Recall: 6.25  Precision: 4.65  F1: 5.33
# CoNLL score: 15.75
# 17 and 14 singletons are removed from the key and system files, respectively
# mentions   Recall: 96.43  Precision: 87.10  F1: 91.53
# muc        Recall: 95.24  Precision: 86.96  F1: 90.91
# bcub       Recall: 94.64  Precision: 81.29  F1: 87.46
# ceafe      Recall: 84.96  Precision: 74.34  F1: 79.30
# lea        Recall: 92.86  Precision: 80.65  F1: 86.32
# CoNLL score: 86.00
# 21 and 22 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.67  Precision: 95.65  F1: 93.62
# muc        Recall: 86.67  Precision: 86.67  F1: 86.67
# bcub       Recall: 86.81  Precision: 85.65  F1: 86.23
# ceafe      Recall: 83.84  Precision: 94.33  F1: 88.78
# lea        Recall: 83.33  Precision: 82.61  F1: 82.97
# CoNLL score: 86.16
# 20 and 20 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 100.00  F1: 100.00
# muc        Recall: 100.00  Precision: 100.00  F1: 100.00
# bcub       Recall: 100.00  Precision: 100.00  F1: 100.00
# ceafe      Recall: 100.00  Precision: 100.00  F1: 100.00
# lea        Recall: 100.00  Precision: 100.00  F1: 100.00
# CoNLL score: 100.00
# 26 and 31 singletons are removed from the key and system files, respectively
# mentions   Recall: 72.22  Precision: 100.00  F1: 83.87
# muc        Recall: 75.00  Precision: 100.00  F1: 85.71
# bcub       Recall: 68.52  Precision: 100.00  F1: 81.32
# ceafe      Recall: 63.33  Precision: 95.00  F1: 76.00
# lea        Recall: 66.67  Precision: 100.00  F1: 80.00
# CoNLL score: 80.76
# 14 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 77.42  Precision: 100.00  F1: 87.27
# muc        Recall: 78.26  Precision: 100.00  F1: 87.80
# bcub       Recall: 70.11  Precision: 100.00  F1: 82.43
# ceafe      Recall: 71.11  Precision: 94.81  F1: 81.27
# lea        Recall: 68.46  Precision: 100.00  F1: 81.28
# CoNLL score: 83.19
# 43 and 45 singletons are removed from the key and system files, respectively
# mentions   Recall: 93.02  Precision: 97.56  F1: 95.24
# muc        Recall: 88.89  Precision: 96.00  F1: 92.31
# bcub       Recall: 87.44  Precision: 95.93  F1: 91.49
# ceafe      Recall: 89.82  Precision: 89.82  F1: 89.82
# lea        Recall: 86.05  Precision: 95.12  F1: 90.36
# CoNLL score: 90.99

# %%
Yechiel_vs_Hadas
# Out:
# {'muc': {'recall': 0.7168888888888889,
#   'precision': 0.7206828259459839,
#   'f1': 0.7126562326562327},
#  'bcub': {'recall': 0.7249098621420996,
#   'precision': 0.731671626984127,
#   'f1': 0.7177272067715376},
#  'ceafe': {'recall': 0.7593090569561156,
#   'precision': 0.711863894275659,
#   'f1': 0.7319277826072959},
#  'lea': {'recall': 0.6837726607079735,
#   'precision': 0.6863095238095238,
#   'f1': 0.6723584868333367}}

# %%
Hadas_vs_Hinoy
# Out:
# {'muc': {'recall': 0.7856178908810488,
#   'precision': 0.6846537842190016,
#   'f1': 0.731024531024531},
#  'bcub': {'recall': 0.8302827380952381,
#   'precision': 0.6930005418021172,
#   'f1': 0.7545260354172078},
#  'ceafe': {'recall': 0.8142013688066321,
#   'precision': 0.7254699248120302,
#   'f1': 0.766310548637868},
#  'lea': {'recall': 0.7791666666666666,
#   'precision': 0.6495609021302945,
#   'f1': 0.7071002786240658}}

# %%
Hinoy_vs_Yechiel
# Out:
# {'muc': {'recall': 0.8576328502415459,
#   'precision': 0.9653333333333333,
#   'f1': 0.9049870454748504},
#  'bcub': {'recall': 0.8257469228418216,
#   'precision': 0.963174266525274,
#   'f1': 0.8829254546779252},
#  'ceafe': {'recall': 0.816221340388007,
#   'precision': 0.9479232804232804,
#   'f1': 0.871736227824463},
#  'lea': {'recall': 0.8090105859798283,
#   'precision': 0.9554612937433722,
#   'f1': 0.8692058945652711}}

# %%
for name, score in third_round_agreement:
    print(name + " Conll score by muc, bcub, ceafe, lea  (without Mentions)")
    df = pd.DataFrame(score)
    df['mean'] = df.mean(axis=1)
    print(df['mean']['f1'])
# Out:
# Yechiel_vs_Hadas No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# 0.7086674272171006
# Hadas_vs_Hinoy No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# 0.7397403484259181
# Hinoy_vs_Yechiel No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# 0.8822136556356275

# %%
should_keep_singleton = False
include_mentions = False
scores = n_annotators_agreement(["Hinoy", "Yechiel", "Hadas"], should_keep_singleton, include_mentions,
                                file_by_annotator, conllu_annotated_files_path)
# Out:
# keep_singletons: False
# include_mentions: False
# Check agreement for 3 files
# name1:  Hinoy
# name2:  Yechiel
# Number of file coules: 5
# name1:  Hinoy
# name2:  Hadas
# Number of file coules: 5
# name1:  Yechiel
# name2:  Hadas
# Number of file coules: 5
# 21 and 22 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.67  Precision: 95.65  F1: 93.62
# muc        Recall: 86.67  Precision: 86.67  F1: 86.67
# bcub       Recall: 86.81  Precision: 85.65  F1: 86.23
# ceafe      Recall: 83.84  Precision: 94.33  F1: 88.78
# lea        Recall: 83.33  Precision: 82.61  F1: 82.97
# CoNLL score: 86.16
# 20 and 20 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 100.00  F1: 100.00
# muc        Recall: 100.00  Precision: 100.00  F1: 100.00
# bcub       Recall: 100.00  Precision: 100.00  F1: 100.00
# ceafe      Recall: 100.00  Precision: 100.00  F1: 100.00
# lea        Recall: 100.00  Precision: 100.00  F1: 100.00
# CoNLL score: 100.00
# 26 and 31 singletons are removed from the key and system files, respectively
# mentions   Recall: 72.22  Precision: 100.00  F1: 83.87
# muc        Recall: 75.00  Precision: 100.00  F1: 85.71
# bcub       Recall: 68.52  Precision: 100.00  F1: 81.32
# ceafe      Recall: 63.33  Precision: 95.00  F1: 76.00
# lea        Recall: 66.67  Precision: 100.00  F1: 80.00
# CoNLL score: 80.76
# 14 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 77.42  Precision: 100.00  F1: 87.27
# muc        Recall: 78.26  Precision: 100.00  F1: 87.80
# bcub       Recall: 70.11  Precision: 100.00  F1: 82.43
# ceafe      Recall: 71.11  Precision: 94.81  F1: 81.27
# lea        Recall: 68.46  Precision: 100.00  F1: 81.28
# CoNLL score: 83.19
# 43 and 45 singletons are removed from the key and system files, respectively
# mentions   Recall: 93.02  Precision: 97.56  F1: 95.24
# muc        Recall: 88.89  Precision: 96.00  F1: 92.31
# bcub       Recall: 87.44  Precision: 95.93  F1: 91.49
# ceafe      Recall: 89.82  Precision: 89.82  F1: 89.82
# lea        Recall: 86.05  Precision: 95.12  F1: 90.36
# CoNLL score: 90.99
# 21 and 24 singletons are removed from the key and system files, respectively
# mentions   Recall: 87.50  Precision: 100.00  F1: 93.33
# muc        Recall: 80.00  Precision: 92.31  F1: 85.71
# bcub       Recall: 82.64  Precision: 95.24  F1: 88.49
# ceafe      Recall: 83.33  Precision: 93.75  F1: 88.24
# lea        Recall: 79.17  Precision: 90.48  F1: 84.44
# CoNLL score: 86.72
# 20 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.71  Precision: 100.00  F1: 92.31
# muc        Recall: 80.00  Precision: 100.00  F1: 88.89
# bcub       Recall: 75.00  Precision: 100.00  F1: 85.71
# ceafe      Recall: 92.86  Precision: 92.86  F1: 92.86
# lea        Recall: 71.43  Precision: 100.00  F1: 83.33
# CoNLL score: 87.70
# 26 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 88.89  Precision: 100.00  F1: 94.12
# muc        Recall: 91.67  Precision: 100.00  F1: 95.65
# bcub       Recall: 88.89  Precision: 100.00  F1: 94.12
# ceafe      Recall: 83.33  Precision: 100.00  F1: 90.91
# lea        Recall: 88.89  Precision: 100.00  F1: 94.12
# CoNLL score: 93.70
# 14 and 17 singletons are removed from the key and system files, respectively
# mentions   Recall: 87.10  Precision: 96.43  F1: 91.53
# muc        Recall: 86.96  Precision: 95.24  F1: 90.91
# bcub       Recall: 81.29  Precision: 94.64  F1: 87.46
# ceafe      Recall: 74.34  Precision: 84.96  F1: 79.30
# lea        Recall: 80.65  Precision: 92.86  F1: 86.32
# CoNLL score: 86.00
# 43 and 52 singletons are removed from the key and system files, respectively
# mentions   Recall: 41.86  Precision: 56.25  F1: 48.00
# muc        Recall: 3.70  Precision: 5.26  F1: 4.35
# bcub       Recall: 18.68  Precision: 25.26  F1: 21.48
# ceafe      Recall: 28.87  Precision: 35.53  F1: 31.86
# lea        Recall: 4.65  Precision: 6.25  F1: 5.33
# CoNLL score: 15.75
# 22 and 24 singletons are removed from the key and system files, respectively
# mentions   Recall: 82.61  Precision: 90.48  F1: 86.36
# muc        Recall: 80.00  Precision: 92.31  F1: 85.71
# bcub       Recall: 75.87  Precision: 90.48  F1: 82.53
# ceafe      Recall: 84.33  Precision: 84.33  F1: 84.33
# lea        Recall: 73.91  Precision: 90.48  F1: 81.36
# CoNLL score: 83.48
# 31 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 81.25  F1: 89.66
# muc        Recall: 100.00  Precision: 81.82  F1: 90.00
# bcub       Recall: 100.00  Precision: 77.08  F1: 87.06
# ceafe      Recall: 95.00  Precision: 76.00  F1: 84.44
# lea        Recall: 100.00  Precision: 75.00  F1: 85.71
# CoNLL score: 86.80
# 20 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.71  Precision: 100.00  F1: 92.31
# muc        Recall: 80.00  Precision: 100.00  F1: 88.89
# bcub       Recall: 75.00  Precision: 100.00  F1: 85.71
# ceafe      Recall: 92.86  Precision: 92.86  F1: 92.86
# lea        Recall: 71.43  Precision: 100.00  F1: 83.33
# CoNLL score: 87.70
# 45 and 52 singletons are removed from the key and system files, respectively
# mentions   Recall: 43.90  Precision: 56.25  F1: 49.32
# muc        Recall: 4.00  Precision: 5.26  F1: 4.55
# bcub       Recall: 19.92  Precision: 25.26  F1: 22.27
# ceafe      Recall: 28.45  Precision: 35.02  F1: 31.40
# lea        Recall: 4.88  Precision: 6.25  F1: 5.48
# CoNLL score: 15.92
# 21 and 17 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.67  Precision: 78.57  F1: 84.62
# muc        Recall: 94.44  Precision: 80.95  F1: 87.18
# bcub       Recall: 91.67  Precision: 73.02  F1: 81.29
# ceafe      Recall: 79.02  Precision: 67.73  F1: 72.94
# lea        Recall: 91.67  Precision: 71.43  F1: 80.29
# CoNLL score: 80.42

# %%
print('Total score of "Hinoy", "Yechiel", "Hadas with mentions: ')
data = {'values': [pd.DataFrame(score).loc['f1'].mean() for score in scores]}
df = pd.DataFrame(data)

print(df['values'].mean())
# Out:
# Total score of "Hinoy", "Yechiel", "Hadas with mentions:
# 0.7768738104262153

# %%
should_keep_singleton = False
include_mentions = False
scores = n_annotators_agreement(["Hinoy", "Yechiel", "Hadas"], should_keep_singleton, include_mentions,
                                file_by_annotator, conllu_annotated_files_path)
# Out:
# keep_singletons: False
# include_mentions: False
# Check agreement for 3 files
# name1:  Hinoy
# name2:  Yechiel
# Number of file coules: 5
# name1:  Hinoy
# name2:  Hadas
# Number of file coules: 5
# name1:  Yechiel
# name2:  Hadas
# Number of file coules: 5
# 21 and 22 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.67  Precision: 95.65  F1: 93.62
# muc        Recall: 86.67  Precision: 86.67  F1: 86.67
# bcub       Recall: 86.81  Precision: 85.65  F1: 86.23
# ceafe      Recall: 83.84  Precision: 94.33  F1: 88.78
# lea        Recall: 83.33  Precision: 82.61  F1: 82.97
# CoNLL score: 86.16
# 20 and 20 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 100.00  F1: 100.00
# muc        Recall: 100.00  Precision: 100.00  F1: 100.00
# bcub       Recall: 100.00  Precision: 100.00  F1: 100.00
# ceafe      Recall: 100.00  Precision: 100.00  F1: 100.00
# lea        Recall: 100.00  Precision: 100.00  F1: 100.00
# CoNLL score: 100.00
# 26 and 31 singletons are removed from the key and system files, respectively
# mentions   Recall: 72.22  Precision: 100.00  F1: 83.87
# muc        Recall: 75.00  Precision: 100.00  F1: 85.71
# bcub       Recall: 68.52  Precision: 100.00  F1: 81.32
# ceafe      Recall: 63.33  Precision: 95.00  F1: 76.00
# lea        Recall: 66.67  Precision: 100.00  F1: 80.00
# CoNLL score: 80.76
# 14 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 77.42  Precision: 100.00  F1: 87.27
# muc        Recall: 78.26  Precision: 100.00  F1: 87.80
# bcub       Recall: 70.11  Precision: 100.00  F1: 82.43
# ceafe      Recall: 71.11  Precision: 94.81  F1: 81.27
# lea        Recall: 68.46  Precision: 100.00  F1: 81.28
# CoNLL score: 83.19
# 43 and 45 singletons are removed from the key and system files, respectively
# mentions   Recall: 93.02  Precision: 97.56  F1: 95.24
# muc        Recall: 88.89  Precision: 96.00  F1: 92.31
# bcub       Recall: 87.44  Precision: 95.93  F1: 91.49
# ceafe      Recall: 89.82  Precision: 89.82  F1: 89.82
# lea        Recall: 86.05  Precision: 95.12  F1: 90.36
# CoNLL score: 90.99
# 21 and 24 singletons are removed from the key and system files, respectively
# mentions   Recall: 87.50  Precision: 100.00  F1: 93.33
# muc        Recall: 80.00  Precision: 92.31  F1: 85.71
# bcub       Recall: 82.64  Precision: 95.24  F1: 88.49
# ceafe      Recall: 83.33  Precision: 93.75  F1: 88.24
# lea        Recall: 79.17  Precision: 90.48  F1: 84.44
# CoNLL score: 86.72
# 20 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.71  Precision: 100.00  F1: 92.31
# muc        Recall: 80.00  Precision: 100.00  F1: 88.89
# bcub       Recall: 75.00  Precision: 100.00  F1: 85.71
# ceafe      Recall: 92.86  Precision: 92.86  F1: 92.86
# lea        Recall: 71.43  Precision: 100.00  F1: 83.33
# CoNLL score: 87.70
# 26 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 88.89  Precision: 100.00  F1: 94.12
# muc        Recall: 91.67  Precision: 100.00  F1: 95.65
# bcub       Recall: 88.89  Precision: 100.00  F1: 94.12
# ceafe      Recall: 83.33  Precision: 100.00  F1: 90.91
# lea        Recall: 88.89  Precision: 100.00  F1: 94.12
# CoNLL score: 93.70
# 14 and 17 singletons are removed from the key and system files, respectively
# mentions   Recall: 87.10  Precision: 96.43  F1: 91.53
# muc        Recall: 86.96  Precision: 95.24  F1: 90.91
# bcub       Recall: 81.29  Precision: 94.64  F1: 87.46
# ceafe      Recall: 74.34  Precision: 84.96  F1: 79.30
# lea        Recall: 80.65  Precision: 92.86  F1: 86.32
# CoNLL score: 86.00
# 43 and 52 singletons are removed from the key and system files, respectively
# mentions   Recall: 41.86  Precision: 56.25  F1: 48.00
# muc        Recall: 3.70  Precision: 5.26  F1: 4.35
# bcub       Recall: 18.68  Precision: 25.26  F1: 21.48
# ceafe      Recall: 28.87  Precision: 35.53  F1: 31.86
# lea        Recall: 4.65  Precision: 6.25  F1: 5.33
# CoNLL score: 15.75
# 22 and 24 singletons are removed from the key and system files, respectively
# mentions   Recall: 82.61  Precision: 90.48  F1: 86.36
# muc        Recall: 80.00  Precision: 92.31  F1: 85.71
# bcub       Recall: 75.87  Precision: 90.48  F1: 82.53
# ceafe      Recall: 84.33  Precision: 84.33  F1: 84.33
# lea        Recall: 73.91  Precision: 90.48  F1: 81.36
# CoNLL score: 83.48
# 31 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 81.25  F1: 89.66
# muc        Recall: 100.00  Precision: 81.82  F1: 90.00
# bcub       Recall: 100.00  Precision: 77.08  F1: 87.06
# ceafe      Recall: 95.00  Precision: 76.00  F1: 84.44
# lea        Recall: 100.00  Precision: 75.00  F1: 85.71
# CoNLL score: 86.80
# 20 and 21 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.71  Precision: 100.00  F1: 92.31
# muc        Recall: 80.00  Precision: 100.00  F1: 88.89
# bcub       Recall: 75.00  Precision: 100.00  F1: 85.71
# ceafe      Recall: 92.86  Precision: 92.86  F1: 92.86
# lea        Recall: 71.43  Precision: 100.00  F1: 83.33
# CoNLL score: 87.70
# 45 and 52 singletons are removed from the key and system files, respectively
# mentions   Recall: 43.90  Precision: 56.25  F1: 49.32
# muc        Recall: 4.00  Precision: 5.26  F1: 4.55
# bcub       Recall: 19.92  Precision: 25.26  F1: 22.27
# ceafe      Recall: 28.45  Precision: 35.02  F1: 31.40
# lea        Recall: 4.88  Precision: 6.25  F1: 5.48
# CoNLL score: 15.92
# 21 and 17 singletons are removed from the key and system files, respectively
# mentions   Recall: 91.67  Precision: 78.57  F1: 84.62
# muc        Recall: 94.44  Precision: 80.95  F1: 87.18
# bcub       Recall: 91.67  Precision: 73.02  F1: 81.29
# ceafe      Recall: 79.02  Precision: 67.73  F1: 72.94
# lea        Recall: 91.67  Precision: 71.43  F1: 80.29
# CoNLL score: 80.42

# %%
print('Total score of "Hinoy", "Yechiel", "Hadas" no mentions: ')
data_no_mentions = {'values': [pd.DataFrame(score).loc['f1'].mean() for score in scores]}
df_no_mentions = pd.DataFrame(data_no_mentions)
print(df_no_mentions['values'].mean())
# Out:
# Total score of "Hinoy", "Yechiel", "Hadas" no mentions:
# 0.7768738104262153

# %%
scores
# Out:
# [{'muc': {'recall': 0.8576328502415459,
#    'precision': 0.9653333333333333,
#    'f1': 0.9049870454748504},
#   'bcub': {'recall': 0.8257469228418216,
#    'precision': 0.963174266525274,
#    'f1': 0.8829254546779252},
#   'ceafe': {'recall': 0.816221340388007,
#    'precision': 0.9479232804232804,
#    'f1': 0.871736227824463},
#   'lea': {'recall': 0.8090105859798283,
#    'precision': 0.9554612937433722,
#    'f1': 0.8692058945652711}},
#  {'muc': {'recall': 0.6846537842190016,
#    'precision': 0.7856178908810489,
#    'f1': 0.731024531024531},
#   'bcub': {'recall': 0.6930005418021172,
#    'precision': 0.8302827380952381,
#    'f1': 0.7545260354172079},
#   'ceafe': {'recall': 0.7254699248120302,
#    'precision': 0.8142013688066319,
#    'f1': 0.7663105486378678},
#   'lea': {'recall': 0.6495609021302945,
#    'precision': 0.7791666666666666,
#    'f1': 0.7071002786240658}},
#  {'muc': {'recall': 0.7168888888888889,
#    'precision': 0.7206828259459839,
#    'f1': 0.7126562326562327},
#   'bcub': {'recall': 0.7249098621420996,
#    'precision': 0.731671626984127,
#    'f1': 0.7177272067715376},
#   'ceafe': {'recall': 0.7593090569561156,
#    'precision': 0.711863894275659,
#    'f1': 0.7319277826072959},
#   'lea': {'recall': 0.6837726607079735,
#    'precision': 0.6863095238095238,
#    'f1': 0.6723584868333367}}]

# %%
df_no_mentions
# Out:
#      values
# 0  0.882214
# 1  0.739740
# 2  0.708667

# %%
print(df_no_mentions.mean())
# Out:
# values    0.776874
# dtype: float64
