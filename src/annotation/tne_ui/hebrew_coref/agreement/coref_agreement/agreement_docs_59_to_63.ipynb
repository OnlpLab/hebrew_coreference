# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from collections import defaultdict
import pandas as pd
from agreement_utils import extract_name, two_annotators_agreement, n_annotators_agreement

# %% [markdown]
# ## Third Round Agreement - Inner Agreement Point-AI

# %%
conllu_annotated_files_path = "../../conllu_out_annotation/documents_59_to_63"

# %%
file_by_annotator = defaultdict(list)
conllu_annotated_files = os.listdir(conllu_annotated_files_path)
for f in conllu_annotated_files:
    file_by_annotator[extract_name(f)].append(f)
keep_singletons = False
calc_with_mentions = False


Arbel_vs_Ido = two_annotators_agreement("Arbel", "Ido", keep_singletons,calc_with_mentions, file_by_annotator, conllu_annotated_files_path, )
Arbel_vs_Elisheva = two_annotators_agreement("Arbel", "Elisheva", keep_singletons,calc_with_mentions, file_by_annotator, conllu_annotated_files_path,)
Elisheva_vs_Ido =  two_annotators_agreement("Elisheva", "Ido", keep_singletons,calc_with_mentions,file_by_annotator, conllu_annotated_files_path)

third_round_agreement = [
    ("Ido vs. Arbel No Singletons", Arbel_vs_Ido),
    ("Arbel vs. Elisheva  No Singletons", Arbel_vs_Elisheva),
    ("Elisheva vs. Ido No Singletons", Elisheva_vs_Ido)]
# Out:
# 27 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.44  Precision: 100.00  F1: 97.14
# muc        Recall: 90.00  Precision: 100.00  F1: 94.74
# bcub       Recall: 90.28  Precision: 100.00  F1: 94.89
# ceafe      Recall: 98.21  Precision: 98.21  F1: 98.21
# lea        Recall: 88.89  Precision: 100.00  F1: 94.12
# CoNLL score: 95.49
# 37 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.44  Precision: 94.44  F1: 94.44
# muc        Recall: 90.91  Precision: 90.91  F1: 90.91
# bcub       Recall: 90.74  Precision: 90.74  F1: 90.74
# ceafe      Recall: 95.24  Precision: 95.24  F1: 95.24
# lea        Recall: 88.89  Precision: 88.89  F1: 88.89
# CoNLL score: 91.44
# 21 and 23 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.12  Precision: 100.00  F1: 96.97
# muc        Recall: 95.00  Precision: 100.00  F1: 97.44
# bcub       Recall: 94.12  Precision: 100.00  F1: 96.97
# ceafe      Recall: 92.86  Precision: 100.00  F1: 96.30
# lea        Recall: 94.12  Precision: 100.00  F1: 96.97
# CoNLL score: 96.92
# 33 and 32 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 97.30  F1: 98.63
# muc        Recall: 100.00  Precision: 96.00  F1: 97.96
# bcub       Recall: 100.00  Precision: 95.50  F1: 97.70
# ceafe      Recall: 98.33  Precision: 98.33  F1: 98.33
# lea        Recall: 100.00  Precision: 94.59  F1: 97.22
# CoNLL score: 97.80
# 27 and 35 singletons are removed from the key and system files, respectively
# mentions   Recall: 50.00  Precision: 90.00  F1: 64.29
# muc        Recall: 40.00  Precision: 80.00  F1: 53.33
# bcub       Recall: 41.67  Precision: 85.00  F1: 55.92
# ceafe      Recall: 52.08  Precision: 83.33  F1: 64.10
# lea        Recall: 37.04  Precision: 80.00  F1: 50.63
# CoNLL score: 56.00
# 37 and 44 singletons are removed from the key and system files, respectively
# mentions   Recall: 61.11  Precision: 100.00  F1: 75.86
# muc        Recall: 54.55  Precision: 100.00  F1: 70.59
# bcub       Recall: 55.56  Precision: 100.00  F1: 71.43
# ceafe      Recall: 66.67  Precision: 93.33  F1: 77.78
# lea        Recall: 53.70  Precision: 100.00  F1: 69.88
# CoNLL score: 72.42
# 49 and 70 singletons are removed from the key and system files, respectively
# mentions   Recall: 48.84  Precision: 95.45  F1: 64.62
# muc        Recall: 37.93  Precision: 84.62  F1: 52.38
# bcub       Recall: 31.50  Precision: 88.64  F1: 46.48
# ceafe      Recall: 38.37  Precision: 59.68  F1: 46.71
# lea        Recall: 25.58  Precision: 81.82  F1: 38.98
# CoNLL score: 46.14
# 21 and 26 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.29  Precision: 100.00  F1: 92.06
# muc        Recall: 85.00  Precision: 100.00  F1: 91.89
# bcub       Recall: 83.33  Precision: 100.00  F1: 90.91
# ceafe      Recall: 84.29  Precision: 98.33  F1: 90.77
# lea        Recall: 82.35  Precision: 100.00  F1: 90.32
# CoNLL score: 90.97
# 33 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 80.56  Precision: 93.55  F1: 86.57
# muc        Recall: 75.00  Precision: 86.36  F1: 80.28
# bcub       Recall: 74.54  Precision: 85.94  F1: 79.83
# ceafe      Recall: 74.72  Precision: 89.67  F1: 81.52
# lea        Recall: 69.44  Precision: 81.25  F1: 74.88
# CoNLL score: 79.13
# 26 and 23 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 90.62  F1: 95.08
# muc        Recall: 100.00  Precision: 89.47  F1: 94.44
# bcub       Recall: 100.00  Precision: 88.54  F1: 93.92
# ceafe      Recall: 98.33  Precision: 90.77  F1: 94.40
# lea        Recall: 100.00  Precision: 87.50  F1: 93.33
# CoNLL score: 94.03
# 35 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 90.00  Precision: 52.94  F1: 66.67
# muc        Recall: 80.00  Precision: 44.44  F1: 57.14
# bcub       Recall: 85.00  Precision: 46.08  F1: 59.76
# ceafe      Recall: 86.00  Precision: 53.75  F1: 66.15
# lea        Recall: 80.00  Precision: 41.18  F1: 54.37
# CoNLL score: 59.36
# 37 and 32 singletons are removed from the key and system files, respectively
# mentions   Recall: 93.55  Precision: 78.38  F1: 85.29
# muc        Recall: 86.36  Precision: 72.00  F1: 78.53
# bcub       Recall: 85.94  Precision: 71.62  F1: 78.13
# ceafe      Recall: 87.67  Precision: 73.06  F1: 79.70
# lea        Recall: 81.25  Precision: 67.57  F1: 73.78
# CoNLL score: 77.53
# 44 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 61.11  F1: 75.86
# muc        Recall: 100.00  Precision: 54.55  F1: 70.59
# bcub       Recall: 100.00  Precision: 55.56  F1: 71.43
# ceafe      Recall: 93.33  Precision: 66.67  F1: 77.78
# lea        Recall: 100.00  Precision: 53.70  F1: 69.88
# CoNLL score: 72.42

# %%
Elisheva_vs_Ido
# Out:
# {'muc': {'recall': 0.9159090909090909,
#   'precision': 0.6511589580010632,
#   'f1': 0.751764904201252},
#  'bcub': {'recall': 0.92734375,
#   'precision': 0.6544931880409821,
#   'f1': 0.7581026735938402},
#  'ceafe': {'recall': 0.9133333333333332,
#   'precision': 0.7106036324786325,
#   'f1': 0.7950714840714841},
#  'lea': {'recall': 0.903125,
#   'precision': 0.6248693546487664,
#   'f1': 0.7284039478279427}}

# %%
print(Arbel_vs_Ido)
Arbel_vs_Elisheva = two_annotators_agreement("Arbel", "Elisheva", keep_singletons,False, file_by_annotator, conllu_annotated_files_path,)
Elisheva_vs_Ido =  two_annotators_agreement("Elisheva", "Ido", keep_singletons,False,file_by_annotator, conllu_annotated_files_path)

third_round_agreement = [
    ("Ido vs. Arbel No Singletons", Arbel_vs_Ido),
    ("Arbel vs. Elisheva  No Singletons", Arbel_vs_Elisheva),
    ("Elisheva vs. Ido No Singletons", Elisheva_vs_Ido)]
# Out:
# {'mentions': {'recall': 0.957516339869281, 'precision': 0.9793543543543544, 'f1': 0.9679678388582498}, 'muc': {'recall': 0.9397727272727272, 'precision': 0.9672727272727273, 'f1': 0.9526025353093022}, 'bcub': {'recall': 0.9378404139433552, 'precision': 0.9655905905905906, 'f1': 0.9507420029847626}, 'ceafe': {'recall': 0.9616071428571429, 'precision': 0.9794642857142857, 'f1': 0.9702050264550265}, 'lea': {'recall': 0.9297385620915033, 'precision': 0.9587087087087087, 'f1': 0.942996137849079}}
# 27 and 35 singletons are removed from the key and system files, respectively
# mentions   Recall: 50.00  Precision: 90.00  F1: 64.29
# muc        Recall: 40.00  Precision: 80.00  F1: 53.33
# bcub       Recall: 41.67  Precision: 85.00  F1: 55.92
# ceafe      Recall: 52.08  Precision: 83.33  F1: 64.10
# lea        Recall: 37.04  Precision: 80.00  F1: 50.63
# CoNLL score: 56.00
# 37 and 44 singletons are removed from the key and system files, respectively
# mentions   Recall: 61.11  Precision: 100.00  F1: 75.86
# muc        Recall: 54.55  Precision: 100.00  F1: 70.59
# bcub       Recall: 55.56  Precision: 100.00  F1: 71.43
# ceafe      Recall: 66.67  Precision: 93.33  F1: 77.78
# lea        Recall: 53.70  Precision: 100.00  F1: 69.88
# CoNLL score: 72.42
# 49 and 70 singletons are removed from the key and system files, respectively
# mentions   Recall: 48.84  Precision: 95.45  F1: 64.62
# muc        Recall: 37.93  Precision: 84.62  F1: 52.38
# bcub       Recall: 31.50  Precision: 88.64  F1: 46.48
# ceafe      Recall: 38.37  Precision: 59.68  F1: 46.71
# lea        Recall: 25.58  Precision: 81.82  F1: 38.98
# CoNLL score: 46.14
# 21 and 26 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.29  Precision: 100.00  F1: 92.06
# muc        Recall: 85.00  Precision: 100.00  F1: 91.89
# bcub       Recall: 83.33  Precision: 100.00  F1: 90.91
# ceafe      Recall: 84.29  Precision: 98.33  F1: 90.77
# lea        Recall: 82.35  Precision: 100.00  F1: 90.32
# CoNLL score: 90.97
# 33 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 80.56  Precision: 93.55  F1: 86.57
# muc        Recall: 75.00  Precision: 86.36  F1: 80.28
# bcub       Recall: 74.54  Precision: 85.94  F1: 79.83
# ceafe      Recall: 74.72  Precision: 89.67  F1: 81.52
# lea        Recall: 69.44  Precision: 81.25  F1: 74.88
# CoNLL score: 79.13
# 26 and 23 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 90.62  F1: 95.08
# muc        Recall: 100.00  Precision: 89.47  F1: 94.44
# bcub       Recall: 100.00  Precision: 88.54  F1: 93.92
# ceafe      Recall: 98.33  Precision: 90.77  F1: 94.40
# lea        Recall: 100.00  Precision: 87.50  F1: 93.33
# CoNLL score: 94.03
# 35 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 90.00  Precision: 52.94  F1: 66.67
# muc        Recall: 80.00  Precision: 44.44  F1: 57.14
# bcub       Recall: 85.00  Precision: 46.08  F1: 59.76
# ceafe      Recall: 86.00  Precision: 53.75  F1: 66.15
# lea        Recall: 80.00  Precision: 41.18  F1: 54.37
# CoNLL score: 59.36
# 37 and 32 singletons are removed from the key and system files, respectively
# mentions   Recall: 93.55  Precision: 78.38  F1: 85.29
# muc        Recall: 86.36  Precision: 72.00  F1: 78.53
# bcub       Recall: 85.94  Precision: 71.62  F1: 78.13
# ceafe      Recall: 87.67  Precision: 73.06  F1: 79.70
# lea        Recall: 81.25  Precision: 67.57  F1: 73.78
# CoNLL score: 77.53
# 44 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 61.11  F1: 75.86
# muc        Recall: 100.00  Precision: 54.55  F1: 70.59
# bcub       Recall: 100.00  Precision: 55.56  F1: 71.43
# ceafe      Recall: 93.33  Precision: 66.67  F1: 77.78
# lea        Recall: 100.00  Precision: 53.70  F1: 69.88
# CoNLL score: 72.42

# %%
Arbel_vs_Elisheva
# Out:
# {'muc': {'recall': 0.5849529780564263,
#   'precision': 0.901958041958042,
#   'f1': 0.6969522060822806},
#  'bcub': {'recall': 0.573182601205857,
#   'precision': 0.9191477272727273,
#   'f1': 0.6891417824685973},
#  'ceafe': {'recall': 0.632250566893424,
#   'precision': 0.8486984126984127,
#   'f1': 0.7217455973977713},
#  'lea': {'recall': 0.5362390434209859,
#   'precision': 0.8861363636363636,
#   'f1': 0.649392361378679}}

# %%
for name, score in third_round_agreement:
    print(name + " Conll score by muc, bcub, ceafe, lea  (without Mentions)")
    df = pd.DataFrame(score)
    df = df.drop(columns=["mentions"])
    df['mean'] = df.mean(axis=1)
    print(df['mean']['f1'])
for name, score in third_round_agreement:
    print(name + " Mention score")
    mentions = pd.DataFrame(score)["mentions"]
    print(mentions['f1'])
# Out:
# Ido vs. Arbel No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# 0.9541364256495426
# Arbel vs. Elisheva  No Singletons Conll score by muc, bcub, ceafe, lea  (without Mentions)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 4
#       2 print(name + " Conll score by muc, bcub, ceafe, lea  (without Mentions)")
#       3 df = pd.DataFrame(score)
# ----> 4 df = df.drop(columns=["mentions"])
#       5 df['mean'] = df.mean(axis=1)
#       6 print(df['mean']['f1'])
#
# File ~/anaconda3/envs/hebrewCoreference/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/hebrewCoreference/lib/python3.9/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/envs/hebrewCoreference/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/hebrewCoreference/lib/python3.9/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/envs/hebrewCoreference/lib/python3.9/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/envs/hebrewCoreference/lib/python3.9/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['mentions'] not found in axis"

# %%
should_keep_singleton = False
include_mentions = False
scores = n_annotators_agreement(["Arbel", "Ido", "Elisheva"], should_keep_singleton,include_mentions, file_by_annotator, conllu_annotated_files_path)
# Out:
# keep_singletons: False
# include_mentions: False
# Check agreement for 3 files
# name1:  Arbel
# name2:  Ido
# Number of file coules: 4
# name1:  Arbel
# name2:  Elisheva
# Number of file coules: 5
# name1:  Ido
# name2:  Elisheva
# Number of file coules: 4
# 27 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.44  Precision: 100.00  F1: 97.14
# muc        Recall: 90.00  Precision: 100.00  F1: 94.74
# bcub       Recall: 90.28  Precision: 100.00  F1: 94.89
# ceafe      Recall: 98.21  Precision: 98.21  F1: 98.21
# lea        Recall: 88.89  Precision: 100.00  F1: 94.12
# CoNLL score: 95.49
# 37 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.44  Precision: 94.44  F1: 94.44
# muc        Recall: 90.91  Precision: 90.91  F1: 90.91
# bcub       Recall: 90.74  Precision: 90.74  F1: 90.74
# ceafe      Recall: 95.24  Precision: 95.24  F1: 95.24
# lea        Recall: 88.89  Precision: 88.89  F1: 88.89
# CoNLL score: 91.44
# 21 and 23 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.12  Precision: 100.00  F1: 96.97
# muc        Recall: 95.00  Precision: 100.00  F1: 97.44
# bcub       Recall: 94.12  Precision: 100.00  F1: 96.97
# ceafe      Recall: 92.86  Precision: 100.00  F1: 96.30
# lea        Recall: 94.12  Precision: 100.00  F1: 96.97
# CoNLL score: 96.92
# 33 and 32 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 97.30  F1: 98.63
# muc        Recall: 100.00  Precision: 96.00  F1: 97.96
# bcub       Recall: 100.00  Precision: 95.50  F1: 97.70
# ceafe      Recall: 98.33  Precision: 98.33  F1: 98.33
# lea        Recall: 100.00  Precision: 94.59  F1: 97.22
# CoNLL score: 97.80
# 27 and 35 singletons are removed from the key and system files, respectively
# mentions   Recall: 50.00  Precision: 90.00  F1: 64.29
# muc        Recall: 40.00  Precision: 80.00  F1: 53.33
# bcub       Recall: 41.67  Precision: 85.00  F1: 55.92
# ceafe      Recall: 52.08  Precision: 83.33  F1: 64.10
# lea        Recall: 37.04  Precision: 80.00  F1: 50.63
# CoNLL score: 56.00
# 37 and 44 singletons are removed from the key and system files, respectively
# mentions   Recall: 61.11  Precision: 100.00  F1: 75.86
# muc        Recall: 54.55  Precision: 100.00  F1: 70.59
# bcub       Recall: 55.56  Precision: 100.00  F1: 71.43
# ceafe      Recall: 66.67  Precision: 93.33  F1: 77.78
# lea        Recall: 53.70  Precision: 100.00  F1: 69.88
# CoNLL score: 72.42
# 49 and 70 singletons are removed from the key and system files, respectively
# mentions   Recall: 48.84  Precision: 95.45  F1: 64.62
# muc        Recall: 37.93  Precision: 84.62  F1: 52.38
# bcub       Recall: 31.50  Precision: 88.64  F1: 46.48
# ceafe      Recall: 38.37  Precision: 59.68  F1: 46.71
# lea        Recall: 25.58  Precision: 81.82  F1: 38.98
# CoNLL score: 46.14
# 21 and 26 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.29  Precision: 100.00  F1: 92.06
# muc        Recall: 85.00  Precision: 100.00  F1: 91.89
# bcub       Recall: 83.33  Precision: 100.00  F1: 90.91
# ceafe      Recall: 84.29  Precision: 98.33  F1: 90.77
# lea        Recall: 82.35  Precision: 100.00  F1: 90.32
# CoNLL score: 90.97
# 33 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 80.56  Precision: 93.55  F1: 86.57
# muc        Recall: 75.00  Precision: 86.36  F1: 80.28
# bcub       Recall: 74.54  Precision: 85.94  F1: 79.83
# ceafe      Recall: 74.72  Precision: 89.67  F1: 81.52
# lea        Recall: 69.44  Precision: 81.25  F1: 74.88
# CoNLL score: 79.13
# 37 and 44 singletons are removed from the key and system files, respectively
# mentions   Recall: 61.11  Precision: 100.00  F1: 75.86
# muc        Recall: 54.55  Precision: 100.00  F1: 70.59
# bcub       Recall: 55.56  Precision: 100.00  F1: 71.43
# ceafe      Recall: 66.67  Precision: 93.33  F1: 77.78
# lea        Recall: 53.70  Precision: 100.00  F1: 69.88
# CoNLL score: 72.42
# 23 and 26 singletons are removed from the key and system files, respectively
# mentions   Recall: 90.62  Precision: 100.00  F1: 95.08
# muc        Recall: 89.47  Precision: 100.00  F1: 94.44
# bcub       Recall: 88.54  Precision: 100.00  F1: 93.92
# ceafe      Recall: 90.77  Precision: 98.33  F1: 94.40
# lea        Recall: 87.50  Precision: 100.00  F1: 93.33
# CoNLL score: 94.03
# 28 and 35 singletons are removed from the key and system files, respectively
# mentions   Recall: 52.94  Precision: 90.00  F1: 66.67
# muc        Recall: 44.44  Precision: 80.00  F1: 57.14
# bcub       Recall: 46.08  Precision: 85.00  F1: 59.76
# ceafe      Recall: 53.75  Precision: 86.00  F1: 66.15
# lea        Recall: 41.18  Precision: 80.00  F1: 54.37
# CoNLL score: 59.36
# 32 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 78.38  Precision: 93.55  F1: 85.29
# muc        Recall: 72.00  Precision: 86.36  F1: 78.53
# bcub       Recall: 71.62  Precision: 85.94  F1: 78.13
# ceafe      Recall: 73.06  Precision: 87.67  F1: 79.70
# lea        Recall: 67.57  Precision: 81.25  F1: 73.78
# CoNLL score: 77.53

# %%
print('Total score of "Arbel", "Ido", "Elisheva" with mentions: ')
data = {'values': [pd.DataFrame(score).loc['f1'].mean() for score in scores]}
df = pd.DataFrame(data)


print(df['values'].mean())
# Out:
# Total score of "Arbel", "Ido", "Elisheva" with mentions:
# 0.8005933883016679

# %%
should_keep_singleton = False
include_mentions = False
scores = n_annotators_agreement(["Arbel", "Ido", "Elisheva"], should_keep_singleton,include_mentions, file_by_annotator, conllu_annotated_files_path)
# Out:
# keep_singletons: False
# include_mentions: False
# Check agreement for 3 files
# name1:  Arbel
# name2:  Ido
# Number of file coules: 4
# name1:  Arbel
# name2:  Elisheva
# Number of file coules: 5
# name1:  Ido
# name2:  Elisheva
# Number of file coules: 4
# 27 and 28 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.44  Precision: 100.00  F1: 97.14
# muc        Recall: 90.00  Precision: 100.00  F1: 94.74
# bcub       Recall: 90.28  Precision: 100.00  F1: 94.89
# ceafe      Recall: 98.21  Precision: 98.21  F1: 98.21
# lea        Recall: 88.89  Precision: 100.00  F1: 94.12
# CoNLL score: 95.49
# 37 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.44  Precision: 94.44  F1: 94.44
# muc        Recall: 90.91  Precision: 90.91  F1: 90.91
# bcub       Recall: 90.74  Precision: 90.74  F1: 90.74
# ceafe      Recall: 95.24  Precision: 95.24  F1: 95.24
# lea        Recall: 88.89  Precision: 88.89  F1: 88.89
# CoNLL score: 91.44
# 21 and 23 singletons are removed from the key and system files, respectively
# mentions   Recall: 94.12  Precision: 100.00  F1: 96.97
# muc        Recall: 95.00  Precision: 100.00  F1: 97.44
# bcub       Recall: 94.12  Precision: 100.00  F1: 96.97
# ceafe      Recall: 92.86  Precision: 100.00  F1: 96.30
# lea        Recall: 94.12  Precision: 100.00  F1: 96.97
# CoNLL score: 96.92
# 33 and 32 singletons are removed from the key and system files, respectively
# mentions   Recall: 100.00  Precision: 97.30  F1: 98.63
# muc        Recall: 100.00  Precision: 96.00  F1: 97.96
# bcub       Recall: 100.00  Precision: 95.50  F1: 97.70
# ceafe      Recall: 98.33  Precision: 98.33  F1: 98.33
# lea        Recall: 100.00  Precision: 94.59  F1: 97.22
# CoNLL score: 97.80
# 27 and 35 singletons are removed from the key and system files, respectively
# mentions   Recall: 50.00  Precision: 90.00  F1: 64.29
# muc        Recall: 40.00  Precision: 80.00  F1: 53.33
# bcub       Recall: 41.67  Precision: 85.00  F1: 55.92
# ceafe      Recall: 52.08  Precision: 83.33  F1: 64.10
# lea        Recall: 37.04  Precision: 80.00  F1: 50.63
# CoNLL score: 56.00
# 37 and 44 singletons are removed from the key and system files, respectively
# mentions   Recall: 61.11  Precision: 100.00  F1: 75.86
# muc        Recall: 54.55  Precision: 100.00  F1: 70.59
# bcub       Recall: 55.56  Precision: 100.00  F1: 71.43
# ceafe      Recall: 66.67  Precision: 93.33  F1: 77.78
# lea        Recall: 53.70  Precision: 100.00  F1: 69.88
# CoNLL score: 72.42
# 49 and 70 singletons are removed from the key and system files, respectively
# mentions   Recall: 48.84  Precision: 95.45  F1: 64.62
# muc        Recall: 37.93  Precision: 84.62  F1: 52.38
# bcub       Recall: 31.50  Precision: 88.64  F1: 46.48
# ceafe      Recall: 38.37  Precision: 59.68  F1: 46.71
# lea        Recall: 25.58  Precision: 81.82  F1: 38.98
# CoNLL score: 46.14
# 21 and 26 singletons are removed from the key and system files, respectively
# mentions   Recall: 85.29  Precision: 100.00  F1: 92.06
# muc        Recall: 85.00  Precision: 100.00  F1: 91.89
# bcub       Recall: 83.33  Precision: 100.00  F1: 90.91
# ceafe      Recall: 84.29  Precision: 98.33  F1: 90.77
# lea        Recall: 82.35  Precision: 100.00  F1: 90.32
# CoNLL score: 90.97
# 33 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 80.56  Precision: 93.55  F1: 86.57
# muc        Recall: 75.00  Precision: 86.36  F1: 80.28
# bcub       Recall: 74.54  Precision: 85.94  F1: 79.83
# ceafe      Recall: 74.72  Precision: 89.67  F1: 81.52
# lea        Recall: 69.44  Precision: 81.25  F1: 74.88
# CoNLL score: 79.13
# 37 and 44 singletons are removed from the key and system files, respectively
# mentions   Recall: 61.11  Precision: 100.00  F1: 75.86
# muc        Recall: 54.55  Precision: 100.00  F1: 70.59
# bcub       Recall: 55.56  Precision: 100.00  F1: 71.43
# ceafe      Recall: 66.67  Precision: 93.33  F1: 77.78
# lea        Recall: 53.70  Precision: 100.00  F1: 69.88
# CoNLL score: 72.42
# 23 and 26 singletons are removed from the key and system files, respectively
# mentions   Recall: 90.62  Precision: 100.00  F1: 95.08
# muc        Recall: 89.47  Precision: 100.00  F1: 94.44
# bcub       Recall: 88.54  Precision: 100.00  F1: 93.92
# ceafe      Recall: 90.77  Precision: 98.33  F1: 94.40
# lea        Recall: 87.50  Precision: 100.00  F1: 93.33
# CoNLL score: 94.03
# 28 and 35 singletons are removed from the key and system files, respectively
# mentions   Recall: 52.94  Precision: 90.00  F1: 66.67
# muc        Recall: 44.44  Precision: 80.00  F1: 57.14
# bcub       Recall: 46.08  Precision: 85.00  F1: 59.76
# ceafe      Recall: 53.75  Precision: 86.00  F1: 66.15
# lea        Recall: 41.18  Precision: 80.00  F1: 54.37
# CoNLL score: 59.36
# 32 and 37 singletons are removed from the key and system files, respectively
# mentions   Recall: 78.38  Precision: 93.55  F1: 85.29
# muc        Recall: 72.00  Precision: 86.36  F1: 78.53
# bcub       Recall: 71.62  Precision: 85.94  F1: 78.13
# ceafe      Recall: 73.06  Precision: 87.67  F1: 79.70
# lea        Recall: 67.57  Precision: 81.25  F1: 73.78
# CoNLL score: 77.53

# %%
print('Total score of "Arbel", "Ido", "Elisheva" no mentions: ')
data_no_mentions = {'values': [pd.DataFrame(score).loc['f1'].mean() for score in scores]}
df_no_mentions = pd.DataFrame(data_no_mentions)
print(df_no_mentions['values'].mean())
# Out:
# Total score of "Arbel", "Ido", "Elisheva" no mentions:
# 0.8005933883016679

# %%
scores
# Out:
# [{'muc': {'recall': 0.9397727272727272,
#    'precision': 0.9672727272727273,
#    'f1': 0.9526025353093022},
#   'bcub': {'recall': 0.9378404139433552,
#    'precision': 0.9655905905905906,
#    'f1': 0.9507420029847626},
#   'ceafe': {'recall': 0.9616071428571429,
#    'precision': 0.9794642857142857,
#    'f1': 0.9702050264550265},
#   'lea': {'recall': 0.9297385620915033,
#    'precision': 0.9587087087087087,
#    'f1': 0.942996137849079}},
#  {'muc': {'recall': 0.5849529780564263,
#    'precision': 0.901958041958042,
#    'f1': 0.6969522060822806},
#   'bcub': {'recall': 0.573182601205857,
#    'precision': 0.9191477272727273,
#    'f1': 0.6891417824685973},
#   'ceafe': {'recall': 0.632250566893424,
#    'precision': 0.8486984126984127,
#    'f1': 0.7217455973977713},
#   'lea': {'recall': 0.5362390434209859,
#    'precision': 0.8861363636363636,
#    'f1': 0.649392361378679}},
#  {'muc': {'recall': 0.6511589580010633,
#    'precision': 0.9159090909090909,
#    'f1': 0.751764904201252},
#   'bcub': {'recall': 0.6544931880409821,
#    'precision': 0.92734375,
#    'f1': 0.7581026735938402},
#   'ceafe': {'recall': 0.7106036324786326,
#    'precision': 0.9133333333333332,
#    'f1': 0.795071484071484},
#   'lea': {'recall': 0.6248693546487665,
#    'precision': 0.903125,
#    'f1': 0.7284039478279427}}]

# %%
print(pd.DataFrame(scores[2]))
# Out:
#                 muc      bcub     ceafe       lea
# recall     0.651159  0.654493  0.710604  0.624869
# precision  0.915909  0.927344  0.913333  0.903125
# f1         0.751765  0.758103  0.795071  0.728404

# %%
print(df_no_mentions)
# Out:
#      values
# 0  0.954136
# 1  0.689308
# 2  0.758336
